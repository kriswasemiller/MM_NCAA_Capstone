# %% [markdown]
# # Imports

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor

# metrics
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from sklearn import metrics

# %% [markdown]
# # Gather/Clean Data

# %%
# Using Stage 2 because it contains 2019 data

df_season_results = pd.read_csv("Data/2021/MDataFiles_Stage2/MRegularSeasonDetailedResults.csv")
df_season_compact = pd.read_csv("Data/2021/MDataFiles_Stage2/MRegularSeasonCompactResults.csv")
df_teams = pd.read_csv("Data/2021/MDataFiles_Stage2/MTeams.csv")
df_teamSpellings = pd.read_csv("Data/2021/MDataFiles_Stage2/MTeamSpellings.csv", sep='\,', engine='python')
df_kenPom = pd.read_csv("Data/2021/kenPom.csv")

df_kenPom.head()
# Out:
#    Rk TeamName_Clean  AdjEM   AdjO  AdjD  AdjT   Luck  SOS_AdjEM  SOS_OppO  \
# 0   1        Gonzaga  36.59  126.0  89.4  74.7  0.018       7.93     105.9
# 1   2       Illinois  30.70  118.8  88.1  70.6  0.026      18.27     112.4
# 2   3       Michigan  30.50  119.3  88.8  66.8  0.026      16.75     111.3
# 3   4         Baylor  29.93  123.0  93.0  68.7  0.047       9.64     106.3
# 4   5        Houston  29.68  119.6  89.9  65.0 -0.011       6.82     103.9
#
#    SOS_OppD  NCSOS_AdjEM
# 0      98.0         6.34
# 1      94.1         9.99
# 2      94.6         2.73
# 3      96.7        -3.71
# 4      97.1         1.99

# %% [markdown]
# ### Merge KenPom Data with TeamIDs

# %%
df_kenPom["TeamName_Clean"] = df_kenPom["TeamName_Clean"].str.lower()
df_kenPom["TeamName_Clean"] = df_kenPom['TeamName_Clean'].str.strip()

kp_df = pd.merge(df_kenPom, df_teamSpellings, left_on=['TeamName_Clean'], right_on = ['TeamNameSpelling'], how='left')
kp_df = kp_df.drop(['TeamNameSpelling'], axis=1)

#Check if any team is blank
kp_df.loc[kp_df.TeamID.isna()]
# Out:
# Empty DataFrame
# Columns: [Rk, TeamName_Clean, AdjEM, AdjO, AdjD, AdjT, Luck, SOS_AdjEM, SOS_OppO, SOS_OppD, NCSOS_AdjEM, TeamID]
# Index: []

# %% [markdown]
# # Data Exploration
# ### 2019 Season Data

# %%
df_2019 = df_season_results.loc[df_season_results.Season == 2019].reset_index(drop=True)
df_2019.shape
# Out:
# (5463, 34)

# %%
df_2019.describe()
# Out:
#        Season       DayNum      WTeamID       WScore      LTeamID  \
# count  5463.0  5463.000000  5463.000000  5463.000000  5463.000000
# mean   2019.0    67.501007  1287.146440    77.887424  1283.345232
# std       0.0    38.309412   103.421203    10.693970   105.168490
# min    2019.0     1.000000  1101.000000    42.000000  1101.000000
# 25%    2019.0    33.000000  1201.000000    71.000000  1191.000000
# 50%    2019.0    71.000000  1285.000000    77.000000  1283.000000
# 75%    2019.0   101.000000  1378.000000    84.000000  1374.000000
# max    2019.0   132.000000  1466.000000   139.000000  1466.000000
#
#             LScore        NumOT         WFGM         WFGA        WFGM3  \
# count  5463.000000  5463.000000  5463.000000  5463.000000  5463.000000
# mean     65.790591     0.002563    27.225883    57.215632     8.366282
# std      10.736197     0.054063     4.530730     6.933486     3.174011
# min      24.000000     0.000000    11.000000    35.000000     0.000000
# 25%      59.000000     0.000000    24.000000    53.000000     6.000000
# Out:
#       Season  DayNum  WTeamID  WScore  LTeamID  LScore WLoc  NumOT  WFGM  \
# 0       2019       1     1104      82     1380      62    H      0    27
# 1       2019       1     1113     102     1168      94    H      0    33
# 2       2019       1     1119      73     1265      69    H      0    22
# 3       2019       1     1120     101     1375      58    H      0    38
# 4       2019       1     1123      86     1232      69    H      0    32
# ...      ...     ...      ...     ...      ...     ...  ...    ...   ...
# 5458    2019     132     1153      69     1222      57    N      0    22
# 5459    2019     132     1209      73     1426      64    N      0    20
# 5460    2019     132     1277      65     1276      60    N      0    22
# 5461    2019     132     1387      55     1382      53    N      0    22
# 5462    2019     132     1463      97     1217      85    H      0    32
#
#       WFGA  WFGM3  WFGA3  WFTM  WFTA  WOR  WDR  WAst  WTO  WStl  WBlk  WPF  \
# 0       55      9     24    19    28   16   29    17   20     3     6   24
# 1       78     10     26    26    44   20   38    11   17     3     2   26
# 2       51      9     30    20    29    6   22    14    6     5     1   22
# 3       74     18     38     7    14   19   23    24   13     9     8   21
# 4       65      7     19    15    20   16   26    14    9     7     5   18
# ...    ...    ...    ...   ...   ...  ...  ...   ...  ...   ...   ...  ...
# 5458    50      6     17    19    25   12   27     6   11     2     3   16
# 5459    50      8     22    25    34    5   31     8   10     4     5   18
# 5460    55      9     23    12    16   11   27    14    9     2     6   10
# 5461    59      4     22     7    15   15   25    13    6     6     8   11
# 5462    53      5     11    28    30    6   23    11    7     4     5   18
#
#       LFGM  LFGA  LFGM3  LFGA3  LFTM  LFTA  LOR  LDR  LAst  LTO  LStl  LBlk  \
# 0       21    55      3     17    17    30   11   20     8   15     7     2
# 1       34    74      7     24    19    26    7   35     7   17     7     3
# 2       27    52      3     15    12    24    9   27     8   12     4     0
# 3       17    46      7     22    17    22    8   19     9   22     4     5
# 4       26    67      6     12    11    18   18   20    11   11     6     5
# ...    ...   ...    ...    ...   ...   ...  ...  ...   ...  ...   ...   ...
# 5458    19    62      8     33    11    18   17   16     8    7     2     4
# 5459    23    64      7     33    11    17   13   28    12   14     5     2
# 5460    21    51      8     25    10    12    3   26    17    6     5     5
# 5461    19    56      7     19     8    10   13   30     9   11     2     7
# 5462    28    62     10     32    19    24   12   15     7    9     1     2
#
#       LPF     Rk TeamName_Clean  AdjEM   AdjO   AdjD  AdjT   Luck  SOS_AdjEM  \
# 0      28    7.0        alabama  24.87  111.7   86.9  73.8  0.031      14.25
# 1      36  110.0    arizona st.   6.82  106.8  100.0  72.8  0.026      12.76
# 2      23  191.0           army  -2.56   98.6  101.2  68.4  0.048      -1.05
# 3      17   63.0         auburn  12.91  111.4   98.5  71.2 -0.044      14.02
# 4      20  143.0       ball st.   2.01  103.3  101.3  70.9 -0.049       4.77
# ...   ...    ...            ...    ...    ...    ...   ...    ...        ...
# 5458   19  117.0     cincinnati   5.95  103.4   97.5  70.9  0.115      10.68
# 5459   24  152.0    georgia st.   1.19  105.7  104.5  70.8  0.076      -1.74
# 5460   11   58.0   michigan st.  13.48  107.3   93.9  68.5  0.090      18.02
# 5461   16   46.0    saint louis  15.56  111.0   95.5  67.7 -0.017       5.39
# 5462   22  120.0           yale   5.26  107.1  101.8  68.2  0.000     -99.00
#
#       SOS_OppO  SOS_OppD  NCSOS_AdjEM  TeamID
# 0        109.7      95.5         9.15  1104.0
# 1        109.1      96.4         8.72  1113.0
# 2        103.0     104.1         3.13  1119.0
# 3        108.8      94.8         5.80  1120.0
# 4        106.3     101.5         4.00  1123.0
# ...        ...       ...          ...     ...
# 5458     107.0      96.4         9.36  1153.0
# 5459     101.2     102.9         4.70  1209.0
# 5460     112.5      94.5        -0.79  1277.0
# 5461     104.6      99.2        -1.58  1387.0
# 5462       0.0     200.0       -99.00  1463.0
#
# [5463 rows x 46 columns]

# %%
#Winner Clean
df_2019['Winning_Team'] = df_2019['TeamName_Clean']

df_2019 = df_2019[['WTeamID', 'Winning_Team', 'WScore', 'AdjEM', 'AdjO', 'AdjD', 'AdjT', 'Luck',
         'SOS_AdjEM','SOS_OppO', 'SOS_OppD', 'NCSOS_AdjEM', 'WFGM', 'WFGA', 'WFGM3', 'WFGA3', 
         'WFTM', 'WFTA', 'WOR', 'WDR','WAst', 'WTO', 'WStl', 'WBlk', 'WPF', 'LTeamID', 
         'LScore', 'LFGM', 'LFGA', 'LFGM3', 'LFGA3', 'LFTM', 'LFTA','LOR', 'LDR', 'LAst', 'LTO', 
         'LStl', 'LBlk', 'LPF']]

# %%
#Loser Data
df_2019 = pd.merge(df_2019, kp_df, left_on =['LTeamID'], right_on=['TeamID'], how='left', validate="m:1")
df_2019
# Out:
#       WTeamID  Winning_Team  WScore  AdjEM_x  AdjO_x  AdjD_x  AdjT_x  Luck_x  \
# 0        1104       alabama      82    24.87   111.7    86.9    73.8   0.031
# 1        1113   arizona st.     102     6.82   106.8   100.0    72.8   0.026
# 2        1119          army      73    -2.56    98.6   101.2    68.4   0.048
# 3        1120        auburn     101    12.91   111.4    98.5    71.2  -0.044
# 4        1123      ball st.      86     2.01   103.3   101.3    70.9  -0.049
# ...       ...           ...     ...      ...     ...     ...     ...     ...
# 5458     1153    cincinnati      69     5.95   103.4    97.5    70.9   0.115
# 5459     1209   georgia st.      73     1.19   105.7   104.5    70.8   0.076
# 5460     1277  michigan st.      65    13.48   107.3    93.9    68.5   0.090
# 5461     1387   saint louis      55    15.56   111.0    95.5    67.7  -0.017
# 5462     1463          yale      97     5.26   107.1   101.8    68.2   0.000
#
#       SOS_AdjEM_x  SOS_OppO_x  SOS_OppD_x  NCSOS_AdjEM_x  WFGM  WFGA  WFGM3  \
# 0           14.25       109.7        95.5           9.15    27    55      9
# 1           12.76       109.1        96.4           8.72    33    78     10
# 2           -1.05       103.0       104.1           3.13    22    51      9
# 3           14.02       108.8        94.8           5.80    38    74     18
# 4            4.77       106.3       101.5           4.00    32    65      7
# ...           ...         ...         ...            ...   ...   ...    ...
# 5458        10.68       107.0        96.4           9.36    22    50      6
# 5459        -1.74       101.2       102.9           4.70    20    50      8
# 5460        18.02       112.5        94.5          -0.79    22    55      9
# 5461         5.39       104.6        99.2          -1.58    22    59      4
# 5462       -99.00         0.0       200.0         -99.00    32    53      5
#
#       WFGA3  WFTM  WFTA  WOR  WDR  WAst  WTO  WStl  WBlk  WPF  LTeamID  \
# 0        24    19    28   16   29    17   20     3     6   24     1380
# 1        26    26    44   20   38    11   17     3     2   26     1168
# 2        30    20    29    6   22    14    6     5     1   22     1265
# 3        38     7    14   19   23    24   13     9     8   21     1375
# 4        19    15    20   16   26    14    9     7     5   18     1232
# ...     ...   ...   ...  ...  ...   ...  ...   ...   ...  ...      ...
# 5458     17    19    25   12   27     6   11     2     3   16     1222
# 5459     22    25    34    5   31     8   10     4     5   18     1426
# 5460     23    12    16   11   27    14    9     2     6   10     1276
# 5461     22     7    15   15   25    13    6     6     8   11     1382
# 5462     11    28    30    6   23    11    7     4     5   18     1217
#
#       LScore  LFGM  LFGA  LFGM3  LFGA3  LFTM  LFTA  LOR  LDR  LAst  LTO  LStl  \
# 0         62    21    55      3     17    17    30   11   20     8   15     7
# 1         94    34    74      7     24    19    26    7   35     7   17     7
# 2         69    27    52      3     15    12    24    9   27     8   12     4
# 3         58    17    46      7     22    17    22    8   19     9   22     4
# 4         69    26    67      6     12    11    18   18   20    11   11     6
# ...      ...   ...   ...    ...    ...   ...   ...  ...  ...   ...  ...   ...
# 5458      57    19    62      8     33    11    18   17   16     8    7     2
# 5459      64    23    64      7     33    11    17   13   28    12   14     5
# 5460      60    21    51      8     25    10    12    3   26    17    6     5
# 5461      53    19    56      7     19     8    10   13   30     9   11     2
# 5462      85    28    62     10     32    19    24   12   15     7    9     1
#
#       LBlk  LPF     Rk     TeamName_Clean  AdjEM_y  AdjO_y  AdjD_y  AdjT_y  \
# 0        2   28  311.0           southern   -12.93    91.3   104.2    70.8
# 1        3   36  260.0  cal st. fullerton    -8.94   101.0   109.9    72.0
# 2        0   23  265.0             marist    -9.54    91.5   101.1    66.3
# 3        5   17  213.0      south alabama    -4.78   103.2   108.0    66.8
# 4        5   20  118.0        indiana st.     5.79   102.7    96.9    67.1
# ...    ...  ...    ...                ...      ...     ...     ...     ...
# 5458     4   19    5.0            houston    29.68   119.6    89.9    65.0
# 5459     2   24  251.0       ut arlington    -7.71    98.2   105.9    69.5
# 5460     5   11    3.0           michigan    30.50   119.3    88.8    66.8
# 5461     7   16   25.0    st. bonaventure    20.61   111.2    90.6    65.1
# 5462     2   22  181.0            harvard    -1.04   101.9   102.9    68.3
#
#       Luck_y  SOS_AdjEM_y  SOS_OppO_y  SOS_OppD_y  NCSOS_AdjEM_y  TeamID
# 0     -0.075       -12.93        93.1       106.0          17.75  1380.0
# 1     -0.044        -1.43       101.5       102.9          -2.45  1168.0
# 2      0.082        -7.49        97.0       104.5         -13.45  1265.0
# 3      0.043        -3.05        99.2       102.3          -1.15  1375.0
# 4      0.079         6.68       105.7        99.0           8.97  1232.0
# ...      ...          ...         ...         ...            ...     ...
# 5458  -0.011         6.82       103.9        97.1           1.99  1222.0
# 5459   0.051        -2.85        99.6       102.5          13.05  1426.0
# 5460   0.026        16.75       111.3        94.6           2.73  1276.0
# 5461   0.014         8.24       105.9        97.7           2.70  1382.0
# 5462   0.000       -99.00         0.0       200.0         -99.00  1217.0
#
# [5463 rows x 52 columns]

# %%
df_2019['Losing_Team'] = df_2019['TeamName_Clean']

df_2019 = df_2019[['WTeamID', 'Winning_Team', 'WScore', 'AdjEM_x', 'AdjO_x', 'AdjD_x','AdjT_x', 'Luck_x', 
         'SOS_AdjEM_x', 'SOS_OppO_x', 'SOS_OppD_x','NCSOS_AdjEM_x', 'WFGM', 'WFGA', 'WFGM3', 'WFGA3',
         'WFTM', 'WFTA','WOR', 'WDR', 'WAst', 'WTO', 'WStl', 'WBlk', 'WPF', 
         'LTeamID', 'Losing_Team', 'LScore','AdjEM_y','AdjO_y', 'AdjD_y', 'AdjT_y', 'Luck_y', 
         'SOS_AdjEM_y', 'SOS_OppO_y','SOS_OppD_y', 'NCSOS_AdjEM_y', 'LFGM', 'LFGA', 'LFGM3', 'LFGA3', 
         'LFTM', 'LFTA', 'LOR', 'LDR', 'LAst','LTO', 'LStl', 'LBlk', 'LPF']]

#Clean Season Df
df_2019.head()
# Out:
#    WTeamID Winning_Team  WScore  AdjEM_x  AdjO_x  AdjD_x  AdjT_x  Luck_x  \
# 0     1104      alabama      82    24.87   111.7    86.9    73.8   0.031
# 1     1113  arizona st.     102     6.82   106.8   100.0    72.8   0.026
# 2     1119         army      73    -2.56    98.6   101.2    68.4   0.048
# 3     1120       auburn     101    12.91   111.4    98.5    71.2  -0.044
# 4     1123     ball st.      86     2.01   103.3   101.3    70.9  -0.049
#
#    SOS_AdjEM_x  SOS_OppO_x  SOS_OppD_x  NCSOS_AdjEM_x  WFGM  WFGA  WFGM3  \
# 0        14.25       109.7        95.5           9.15    27    55      9
# 1        12.76       109.1        96.4           8.72    33    78     10
# 2        -1.05       103.0       104.1           3.13    22    51      9
# 3        14.02       108.8        94.8           5.80    38    74     18
# 4         4.77       106.3       101.5           4.00    32    65      7
#
#    WFGA3  WFTM  WFTA  WOR  WDR  WAst  WTO  WStl  WBlk  WPF  LTeamID  \
# 0     24    19    28   16   29    17   20     3     6   24     1380
# 1     26    26    44   20   38    11   17     3     2   26     1168
# 2     30    20    29    6   22    14    6     5     1   22     1265
# 3     38     7    14   19   23    24   13     9     8   21     1375
# 4     19    15    20   16   26    14    9     7     5   18     1232
#
#          Losing_Team  LScore  AdjEM_y  AdjO_y  AdjD_y  AdjT_y  Luck_y  \
# 0           southern      62   -12.93    91.3   104.2    70.8  -0.075
# 1  cal st. fullerton      94    -8.94   101.0   109.9    72.0  -0.044
# 2             marist      69    -9.54    91.5   101.1    66.3   0.082
# 3      south alabama      58    -4.78   103.2   108.0    66.8   0.043
# 4        indiana st.      69     5.79   102.7    96.9    67.1   0.079
#
#    SOS_AdjEM_y  SOS_OppO_y  SOS_OppD_y  NCSOS_AdjEM_y  LFGM  LFGA  LFGM3  \
# 0       -12.93        93.1       106.0          17.75    21    55      3
# 1        -1.43       101.5       102.9          -2.45    34    74      7
# 2        -7.49        97.0       104.5         -13.45    27    52      3
# 3        -3.05        99.2       102.3          -1.15    17    46      7
# 4         6.68       105.7        99.0           8.97    26    67      6
#
#    LFGA3  LFTM  LFTA  LOR  LDR  LAst  LTO  LStl  LBlk  LPF
# 0     17    17    30   11   20     8   15     7     2   28
# 1     24    19    26    7   35     7   17     7     3   36
# 2     15    12    24    9   27     8   12     4     0   23
# 3     22    17    22    8   19     9   22     4     5   17
# 4     12    11    18   18   20    11   11     6     5   20

# %% [markdown]
# # Correlations

# %%
plt.figure(figsize=(14,10))
sns.heatmap(df_2019.corr())

plt.title('Correlations')
plt.show()

# %%
df_2019.corr()['WScore']
# Out:
# WTeamID         -0.036552
# WScore           1.000000
# AdjEM_x          0.052870
# AdjO_x           0.089037
# AdjD_x           0.001465
# AdjT_x           0.137430
# Luck_x          -0.034872
# SOS_AdjEM_x      0.028607
# SOS_OppO_x       0.030855
# SOS_OppD_x      -0.017382
# NCSOS_AdjEM_x    0.031536
# WFGM             0.821011
# WFGA             0.466815
# WFGM3            0.458179
# WFGA3            0.263748
# WFTM             0.297412
# WFTA             0.258461
# WOR              0.090023
# WDR              0.105484
# WAst             0.537566
# WTO             -0.059317
# WStl             0.101629
# WBlk             0.031538
# WPF              0.203970
# LTeamID         -0.012873
# LScore           0.623662
# AdjEM_y         -0.091764
# AdjO_y          -0.032539
# AdjD_y           0.141880
# AdjT_y           0.121670
# Luck_y           0.033947
# SOS_AdjEM_y     -0.018204
# SOS_OppO_y       0.005818
# SOS_OppD_y       0.004517
# NCSOS_AdjEM_y    0.018125
# LFGM             0.516273
# LFGA             0.370176
# LFGM3            0.289665
# LFGA3            0.184602
# LFTM             0.265916
# LFTA             0.257217
# LOR              0.044286
# LDR             -0.166433
# LAst             0.271738
# LTO              0.038496
# LStl            -0.001893
# LBlk            -0.084215
# LPF              0.207284
# Name: WScore, dtype: float64

# %%
regress_df = df_2019.drop(['Winning_Team', 'Losing_Team', 'WTeamID', 'LTeamID', 'LScore', 'WFGM', 'WFGM3', 
                           'WFTM', 'LFGM', 'LFGM3', 'LFTM', ], axis=1)
regress_df.head()
# Out:
#    WScore  AdjEM_x  AdjO_x  AdjD_x  AdjT_x  Luck_x  SOS_AdjEM_x  SOS_OppO_x  \
# 0      82    24.87   111.7    86.9    73.8   0.031        14.25       109.7
# 1     102     6.82   106.8   100.0    72.8   0.026        12.76       109.1
# 2      73    -2.56    98.6   101.2    68.4   0.048        -1.05       103.0
# 3     101    12.91   111.4    98.5    71.2  -0.044        14.02       108.8
# 4      86     2.01   103.3   101.3    70.9  -0.049         4.77       106.3
#
#    SOS_OppD_x  NCSOS_AdjEM_x  WFGA  WFGA3  WFTA  WOR  WDR  WAst  WTO  WStl  \
# 0        95.5           9.15    55     24    28   16   29    17   20     3
# 1        96.4           8.72    78     26    44   20   38    11   17     3
# 2       104.1           3.13    51     30    29    6   22    14    6     5
# 3        94.8           5.80    74     38    14   19   23    24   13     9
# 4       101.5           4.00    65     19    20   16   26    14    9     7
#
#    WBlk  WPF  AdjEM_y  AdjO_y  AdjD_y  AdjT_y  Luck_y  SOS_AdjEM_y  \
# 0     6   24   -12.93    91.3   104.2    70.8  -0.075       -12.93
# 1     2   26    -8.94   101.0   109.9    72.0  -0.044        -1.43
# 2     1   22    -9.54    91.5   101.1    66.3   0.082        -7.49
# 3     8   21    -4.78   103.2   108.0    66.8   0.043        -3.05
# 4     5   18     5.79   102.7    96.9    67.1   0.079         6.68
#
#    SOS_OppO_y  SOS_OppD_y  NCSOS_AdjEM_y  LFGA  LFGA3  LFTA  LOR  LDR  LAst  \
# 0        93.1       106.0          17.75    55     17    30   11   20     8
# 1       101.5       102.9          -2.45    74     24    26    7   35     7
# 2        97.0       104.5         -13.45    52     15    24    9   27     8
# 3        99.2       102.3          -1.15    46     22    22    8   19     9
# 4       105.7        99.0           8.97    67     12    18   18   20    11
#
#    LTO  LStl  LBlk  LPF
# 0   15     7     2   28
# 1   17     7     3   36
# 2   12     4     0   23
# 3   22     4     5   17
# 4   11     6     5   20

# %%
regress_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5463 entries, 0 to 5462
# Data columns (total 39 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   WScore         5463 non-null   int64
#  1   AdjEM_x        5453 non-null   float64
#  2   AdjO_x         5453 non-null   float64
#  3   AdjD_x         5453 non-null   float64
#  4   AdjT_x         5453 non-null   float64
#  5   Luck_x         5453 non-null   float64
#  6   SOS_AdjEM_x    5453 non-null   float64
#  7   SOS_OppO_x     5453 non-null   float64
#  8   SOS_OppD_x     5453 non-null   float64
#  9   NCSOS_AdjEM_x  5453 non-null   float64
#  10  WFGA           5463 non-null   int64
#  11  WFGA3          5463 non-null   int64
#  12  WFTA           5463 non-null   int64
#  13  WOR            5463 non-null   int64
#  14  WDR            5463 non-null   int64
#  15  WAst           5463 non-null   int64
#  16  WTO            5463 non-null   int64
#  17  WStl           5463 non-null   int64
#  18  WBlk           5463 non-null   int64
#  19  WPF            5463 non-null   int64
#  20  AdjEM_y        5443 non-null   float64
#  21  AdjO_y         5443 non-null   float64
#  22  AdjD_y         5443 non-null   float64
#  23  AdjT_y         5443 non-null   float64
#  24  Luck_y         5443 non-null   float64
#  25  SOS_AdjEM_y    5443 non-null   float64
#  26  SOS_OppO_y     5443 non-null   float64
#  27  SOS_OppD_y     5443 non-null   float64
#  28  NCSOS_AdjEM_y  5443 non-null   float64
#  29  LFGA           5463 non-null   int64
#  30  LFGA3          5463 non-null   int64
#  31  LFTA           5463 non-null   int64
#  32  LOR            5463 non-null   int64
#  33  LDR            5463 non-null   int64
#  34  LAst           5463 non-null   int64
#  35  LTO            5463 non-null   int64
#  36  LStl           5463 non-null   int64
#  37  LBlk           5463 non-null   int64
#  38  LPF            5463 non-null   int64
# dtypes: float64(18), int64(21)
# memory usage: 1.8 MB

# %%
regress_df.dropna(axis = 0, how = "any", inplace = True)
regress_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5433 entries, 0 to 5462
# Data columns (total 39 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   WScore         5433 non-null   int64
#  1   AdjEM_x        5433 non-null   float64
#  2   AdjO_x         5433 non-null   float64
#  3   AdjD_x         5433 non-null   float64
#  4   AdjT_x         5433 non-null   float64
#  5   Luck_x         5433 non-null   float64
#  6   SOS_AdjEM_x    5433 non-null   float64
#  7   SOS_OppO_x     5433 non-null   float64
#  8   SOS_OppD_x     5433 non-null   float64
#  9   NCSOS_AdjEM_x  5433 non-null   float64
#  10  WFGA           5433 non-null   int64
#  11  WFGA3          5433 non-null   int64
#  12  WFTA           5433 non-null   int64
#  13  WOR            5433 non-null   int64
#  14  WDR            5433 non-null   int64
#  15  WAst           5433 non-null   int64
#  16  WTO            5433 non-null   int64
#  17  WStl           5433 non-null   int64
#  18  WBlk           5433 non-null   int64
#  19  WPF            5433 non-null   int64
#  20  AdjEM_y        5433 non-null   float64
#  21  AdjO_y         5433 non-null   float64
#  22  AdjD_y         5433 non-null   float64
#  23  AdjT_y         5433 non-null   float64
#  24  Luck_y         5433 non-null   float64
#  25  SOS_AdjEM_y    5433 non-null   float64
#  26  SOS_OppO_y     5433 non-null   float64
#  27  SOS_OppD_y     5433 non-null   float64
#  28  NCSOS_AdjEM_y  5433 non-null   float64
#  29  LFGA           5433 non-null   int64
#  30  LFGA3          5433 non-null   int64
#  31  LFTA           5433 non-null   int64
#  32  LOR            5433 non-null   int64
#  33  LDR            5433 non-null   int64
#  34  LAst           5433 non-null   int64
#  35  LTO            5433 non-null   int64
#  36  LStl           5433 non-null   int64
#  37  LBlk           5433 non-null   int64
#  38  LPF            5433 non-null   int64
# dtypes: float64(18), int64(21)
# memory usage: 1.7 MB

# %% [markdown]
# # Model Building

# %%
def in_sample_results(regression, y_train, in_preds):
    ev = metrics.explained_variance_score(y_train, in_preds)
    mae =metrics.mean_absolute_error(y_train, in_preds) 
    mse=metrics.mean_squared_error(y_train, in_preds) 
    r2=metrics.r2_score(y_train, in_preds)
    
    print(f'{regression}')
    print('----------------------------------------------')
    print('IN SAMPLE RESULTS')
    print('Explained Variance: ', ev)
    print('r2: ', r2)
    print('MAE: ', mae)
    print('MSE: ', mse)
    print('RMSE ', np.sqrt(mse))
    print('----------------------------------------------')

# %%
def out_sample_results(y_test, out_preds):
    ev = metrics.explained_variance_score(y_test, out_preds)
    mae =metrics.mean_absolute_error(y_test, out_preds) 
    mse=metrics.mean_squared_error(y_test, out_preds) 
    r2=metrics.r2_score(y_test, out_preds)
    
    print('----------------------------------------------')
    print('OUT SAMPLE RESULTS')
    print('Explained Variance: ', ev)
    print('r2: ', r2)
    print('MAE: ', mae)
    print('MSE: ', mse)
    print('RMSE ', np.sqrt(mse))
    print('----------------------------------------------')

# %%
# get pandas columns for prediction
target = regress_df["WScore"]
features = regress_df.drop(["WScore"], axis=1)

# convert to lists/arrays (MUST HAPPEN)
X = np.array(features)
y = np.array(target)

# train/test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123)

# %% [markdown]
# ## Linear Regressions

# %%
# train the model
reg = LinearRegression()
reg.fit(X_train, y_train)

#get predictions
in_sample_preds = reg.predict(X_train)
out_sample_preds = reg.predict(X_test)

#metric report
in_sample_results('Linear Regression', y_train, in_sample_preds)
out_sample_results(y_test, out_sample_preds)

# predicted vs actual
plt.figure(figsize=(10,6))
plt.scatter(y_test, out_sample_preds)
plt.plot(y_test, y_test)

plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Actual vs Predicted")

plt.show()
# Out:
# Linear Regression
# ----------------------------------------------
# IN SAMPLE RESULTS
# Explained Variance:  0.9079838468852701
# r2:  0.9079838468852701
# MAE:  2.52605278741288
# MSE:  10.399621027505784
# RMSE  3.224844341593216
# ----------------------------------------------
# ----------------------------------------------
# OUT SAMPLE RESULTS
# Explained Variance:  0.9024085253254426
# r2:  0.9018689281941255
# MAE:  2.605798012394647
# MSE:  10.997192608283914
# RMSE  3.316201533122484
# ----------------------------------------------

# %%
# train the model
ridge = Ridge()
ridge.fit(X_train, y_train)

#get predictions
in_sample_preds = ridge.predict(X_train)
out_sample_preds = ridge.predict(X_test)

#metric report
in_sample_results('Ridge Regression', y_train, in_sample_preds)
out_sample_results(y_test, out_sample_preds)

# predicted vs actual
plt.figure(figsize=(10,6))
plt.scatter(y_test, out_sample_preds)
plt.plot(y_test, y_test)

plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Actual vs Predicted")

plt.show()
# Out:
# Ridge Regression
# ----------------------------------------------
# IN SAMPLE RESULTS
# Explained Variance:  0.9079734211525423
# r2:  0.9079734211525423
# MAE:  2.526431598045954
# MSE:  10.400799338765632
# RMSE  3.225027029152722
# ----------------------------------------------
# ----------------------------------------------
# OUT SAMPLE RESULTS
# Explained Variance:  0.9025843074164197
# r2:  0.9020456503029255
# MAE:  2.6034143755956185
# MSE:  10.977388003760069
# RMSE  3.3132141499999768
# ----------------------------------------------

# %%
# train the model
lasso = Lasso()
lasso.fit(X_train, y_train)

#get predictions
in_sample_preds = lasso.predict(X_train)
out_sample_preds = lasso.predict(X_test)

#metric report
in_sample_results('Lasso Regression', y_train, in_sample_preds)
out_sample_results(y_test, out_sample_preds)

# predicted vs actual
plt.figure(figsize=(10,6))
plt.scatter(y_test, out_sample_preds)
plt.plot(y_test, y_test)

plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Actual vs Predicted")

plt.show()
# Out:
# Lasso Regression
# ----------------------------------------------
# IN SAMPLE RESULTS
# Explained Variance:  0.8982666110081033
# r2:  0.8982666110081033
# MAE:  2.67851974290486
# MSE:  11.497858316684958
# RMSE  3.390849202881921
# ----------------------------------------------
# ----------------------------------------------
# OUT SAMPLE RESULTS
# Explained Variance:  0.8917164592875177
# r2:  0.8914635671695821
# MAE:  2.7576560028898487
# MSE:  12.16328360514984
# RMSE  3.487589942230858
# ----------------------------------------------

# %%
# train the model
en = ElasticNet()
en.fit(X_train, y_train)

#get predictions
in_sample_preds = en.predict(X_train)
out_sample_preds = en.predict(X_test)

#metric report
in_sample_results('Elastic Net Regression', y_train, in_sample_preds)
out_sample_results(y_test, out_sample_preds)

# predicted vs actual
plt.figure(figsize=(10,6))
plt.scatter(y_test, out_sample_preds)
plt.plot(y_test, y_test)

plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Actual vs Predicted")

plt.show()
# Out:
# Elastic Net Regression
# ----------------------------------------------
# IN SAMPLE RESULTS
# Explained Variance:  0.8984227204928161
# r2:  0.8984227204928161
# MAE:  2.6781474231294675
# MSE:  11.480214898384393
# RMSE  3.388246581697441
# ----------------------------------------------
# ----------------------------------------------
# OUT SAMPLE RESULTS
# Explained Variance:  0.8920853058932144
# r2:  0.8917271223922949
# MAE:  2.756608320551158
# MSE:  12.133747929101933
# RMSE  3.4833529722240226
# ----------------------------------------------

# %% [markdown]
# ## Tree Based Models

# %%
# train the model
dt = DecisionTreeRegressor()
dt.fit(X_train, y_train)

#get predictions
in_sample_preds = dt.predict(X_train)
out_sample_preds = dt.predict(X_test)

#metric report
in_sample_results('Decision Tree Regression', y_train, in_sample_preds)
out_sample_results(y_test, out_sample_preds)

# predicted vs actual
plt.figure(figsize=(10,6))
plt.scatter(y_test, out_sample_preds)
plt.plot(y_test, y_test)

plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Actual vs Predicted")

plt.show()
# Out:
# Decision Tree Regression
# ----------------------------------------------
# IN SAMPLE RESULTS
# Explained Variance:  1.0
# r2:  1.0
# MAE:  0.0
# MSE:  0.0
# RMSE  0.0
# ----------------------------------------------
# ----------------------------------------------
# OUT SAMPLE RESULTS
# Explained Variance:  0.3053318080582086
# r2:  0.3053055193257904
# MAE:  6.961361545538178
# MSE:  77.85188592456302
# RMSE  8.823371573529192
# ----------------------------------------------

# %%
# train the model
rf = RandomForestRegressor()
rf.fit(X_train, y_train)

#get predictions
in_sample_preds = rf.predict(X_train)
out_sample_preds = rf.predict(X_test)

#metric report
in_sample_results('Random Forest Regression', y_train, in_sample_preds)
out_sample_results(y_test, out_sample_preds)

# predicted vs actual
plt.figure(figsize=(10,6))
plt.scatter(y_test, out_sample_preds)
plt.plot(y_test, y_test)

plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Actual vs Predicted")

plt.show()
# Out:
# Random Forest Regression
# ----------------------------------------------
# IN SAMPLE RESULTS
# Explained Variance:  0.9585396864152657
# r2:  0.9585393537085691
# MAE:  1.6785112747353887
# MSE:  4.685862149102623
# RMSE  2.16468523095221
# ----------------------------------------------
# ----------------------------------------------
# OUT SAMPLE RESULTS
# Explained Variance:  0.6986835739058208
# r2:  0.6986693425854869
# MAE:  4.63559337626495
# MSE:  33.76903173873045
# RMSE  5.811112779729064
# ----------------------------------------------

# %%
# train the model
ada = AdaBoostRegressor()
ada.fit(X_train, y_train)

#get predictions
in_sample_preds = ada.predict(X_train)
out_sample_preds = ada.predict(X_test)

#metric report
in_sample_results('Ada Boost Regression', y_train, in_sample_preds)
out_sample_results(y_test, out_sample_preds)

# predicted vs actual
plt.figure(figsize=(10,6))
plt.scatter(y_test, out_sample_preds)
plt.plot(y_test, y_test)

plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Actual vs Predicted")

plt.show()
# Out:
# Ada Boost Regression
# ----------------------------------------------
# IN SAMPLE RESULTS
# Explained Variance:  0.6577305972485696
# r2:  0.6542056501733304
# MAE:  5.05075496780546
# MSE:  39.08150982106702
# RMSE  6.251520600707241
# ----------------------------------------------
# ----------------------------------------------
# OUT SAMPLE RESULTS
# Explained Variance:  0.6058863293662291
# r2:  0.6031922839676376
# MAE:  5.296064279500397
# MSE:  44.468798733734836
# RMSE  6.668492988204669
# ----------------------------------------------

# %%
# train the model
gb = GradientBoostingRegressor()
gb.fit(X_train, y_train)

#get predictions
in_sample_preds = gb.predict(X_train)
out_sample_preds = gb.predict(X_test)

#metric report
in_sample_results('Gradient Boosting Regression', y_train, in_sample_preds)
out_sample_results(y_test, out_sample_preds)

# predicted vs actual
plt.figure(figsize=(10,6))
plt.scatter(y_test, out_sample_preds)
plt.plot(y_test, y_test)

plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Actual vs Predicted")

plt.show()
# Out:
# Gradient Boosting Regression
# ----------------------------------------------
# IN SAMPLE RESULTS
# Explained Variance:  0.8509614893625815
# r2:  0.8509614893625815
# MAE:  3.27564663810876
# MSE:  16.844260237661764
# RMSE  4.1041759511090365
# ----------------------------------------------
# ----------------------------------------------
# OUT SAMPLE RESULTS
# Explained Variance:  0.7884538366391183
# r2:  0.7882769272937141
# MAE:  3.8154776466494718
# MSE:  23.727035355068217
# RMSE  4.87104047971973
# ----------------------------------------------

# %%
# train the model
xgb = XGBRegressor()
xgb.fit(X_train, y_train)

#get predictions
in_sample_preds = xgb.predict(X_train)
out_sample_preds = xgb.predict(X_test)

#metric report
in_sample_results('XTREME Gradient Boosting Regression', y_train, in_sample_preds)
out_sample_results(y_test, out_sample_preds)

# predicted vs actual
plt.figure(figsize=(10,6))
plt.scatter(y_test, out_sample_preds)
plt.plot(y_test, y_test)

plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Actual vs Predicted")

plt.show()
# Out:
# XTREME Gradient Boosting Regression
# ----------------------------------------------
# IN SAMPLE RESULTS
# Explained Variance:  0.9905227834646333
# r2:  0.9905227832091713
# MAE:  0.7446393216199387
# MSE:  1.0711104483714322
# RMSE  1.034944659569502
# ----------------------------------------------
# ----------------------------------------------
# OUT SAMPLE RESULTS
# Explained Variance:  0.8067808771615386
# r2:  0.8066467197868072
# MAE:  3.6375496486183034
# MSE:  21.668399466321517
# RMSE  4.654932810075943
# ----------------------------------------------

# %%
# train the model
knn = KNeighborsRegressor(n_neighbors=5)
knn.fit(X_train, y_train)

#get predictions
in_sample_preds = knn.predict(X_train)
out_sample_preds = knn.predict(X_test)

#metric report
in_sample_results('KNN Regression', y_train, in_sample_preds)
out_sample_results(y_test, out_sample_preds)

# predicted vs actual
plt.figure(figsize=(10,6))
plt.scatter(y_test, out_sample_preds)
plt.plot(y_test, y_test)

plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Actual vs Predicted")

plt.show()
# Out:
# KNN Regression
# ----------------------------------------------
# IN SAMPLE RESULTS
# Explained Variance:  0.6116239910127104
# r2:  0.6088203522772785
# MAE:  5.283847215830648
# MSE:  44.210934192360796
# RMSE  6.64913033353692
# ----------------------------------------------
# ----------------------------------------------
# OUT SAMPLE RESULTS
# Explained Variance:  0.42074924624366394
# r2:  0.41841631087385944
# MAE:  6.434038638454461
# MSE:  65.17597056117755
# RMSE  8.073163603023138
# ----------------------------------------------

# %% [markdown]
# # GRADIENT BOOST MODEL

# %%
# train the model
gb = GradientBoostingRegressor()
gb.fit(X_train, y_train)

#get predictions
in_sample_preds = gb.predict(X)

#metric report
in_sample_results('Gradient Boost Regression', y, in_sample_preds)

# predicted vs actual
plt.figure(figsize=(10,6))
plt.scatter(y_test, out_sample_preds)
plt.plot(y_test, y_test)

plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Actual vs Predicted")

plt.show()
# Out:
# Gradient Boost Regression
# ----------------------------------------------
# IN SAMPLE RESULTS
# Explained Variance:  0.8385226725928512
# r2:  0.8385155489734588
# MAE:  3.3836525844153584
# MSE:  18.22086771440167
# RMSE  4.268590834737111
# ----------------------------------------------

# %% [markdown]
# # Testing

# %%
avg_df = df_2019.groupby("Winning_Team").mean()
avg_df['WTeamID'] = avg_df['WTeamID'].astype(int)
avg_df
# Out:
#                    WTeamID     WScore  AdjEM_x  AdjO_x  AdjD_x  AdjT_x  \
# Winning_Team
# abilene christian     1101  73.521739    10.39   103.3    92.9    69.9
# air force             1102  77.461538   -16.66    94.2   110.9    63.1
# youngstown st.     19.400000   9.200000  24.800000  12.000000  11.300000
#
#                        LStl      LBlk        LPF
# Winning_Team
# abilene christian  4.782609  3.130435  18.217391
# air force          5.307692  2.000000  18.000000
# akron              5.666667  2.266667  19.333333
# alabama            5.111111  3.944444  20.777778
# alabama a&m        6.200000  2.400000  17.800000
# ...                     ...       ...        ...
# wright st.         5.421053  3.263158  19.684211
# wyoming            5.714286  2.857143  19.714286
# xavier             7.055556  2.222222  18.500000
# yale               6.666667  2.476190  17.476190
# youngstown st.     3.700000  3.400000  15.000000
#
# [352 rows x 48 columns]

# %%
full_avg = pd.merge(kp_df, avg_df, left_on='TeamID', right_on='WTeamID', how='left')

# %%
#Drop NA values (Teams that did not win a game)

full_avg.dropna(axis=0, how='any', inplace=True)
full_avg.columns
# Out:
# Index(['Rk', 'TeamName_Clean', 'AdjEM', 'AdjO', 'AdjD', 'AdjT', 'Luck',
#        'SOS_AdjEM', 'SOS_OppO', 'SOS_OppD', 'NCSOS_AdjEM', 'TeamID', 'WTeamID',
#        'WScore', 'AdjEM_x', 'AdjO_x', 'AdjD_x', 'AdjT_x', 'Luck_x',
#        'SOS_AdjEM_x', 'SOS_OppO_x', 'SOS_OppD_x', 'NCSOS_AdjEM_x', 'WFGM',
#        'WFGA', 'WFGM3', 'WFGA3', 'WFTM', 'WFTA', 'WOR', 'WDR', 'WAst', 'WTO',
#        'WStl', 'WBlk', 'WPF', 'LTeamID', 'LScore', 'AdjEM_y', 'AdjO_y',
#        'AdjD_y', 'AdjT_y', 'Luck_y', 'SOS_AdjEM_y', 'SOS_OppO_y', 'SOS_OppD_y',
#        'NCSOS_AdjEM_y', 'LFGM', 'LFGA', 'LFGM3', 'LFGA3', 'LFTM', 'LFTA',
#        'LOR', 'LDR', 'LAst', 'LTO', 'LStl', 'LBlk', 'LPF'],
#       dtype='object')

# %%
features.columns
# Out:
# Index(['AdjEM_x', 'AdjO_x', 'AdjD_x', 'AdjT_x', 'Luck_x', 'SOS_AdjEM_x',
#        'SOS_OppO_x', 'SOS_OppD_x', 'NCSOS_AdjEM_x', 'WFGA', 'WFGA3', 'WFTA',
#        'WOR', 'WDR', 'WAst', 'WTO', 'WStl', 'WBlk', 'WPF', 'AdjEM_y', 'AdjO_y',
#        'AdjD_y', 'AdjT_y', 'Luck_y', 'SOS_AdjEM_y', 'SOS_OppO_y', 'SOS_OppD_y',
#        'NCSOS_AdjEM_y', 'LFGA', 'LFGA3', 'LFTA', 'LOR', 'LDR', 'LAst', 'LTO',
#        'LStl', 'LBlk', 'LPF'],
#       dtype='object')

# %%
full_avg
# Out:
#       Rk          TeamName_Clean  AdjEM   AdjO   AdjD  AdjT   Luck  SOS_AdjEM  \
# 0      1                 gonzaga  36.59  126.0   89.4  74.7  0.018       7.93
# 1      2                illinois  30.70  118.8   88.1  70.6  0.026      18.27
# 2      3                michigan  30.50  119.3   88.8  66.8  0.026      16.75
# 3      4                  baylor  29.93  123.0   93.0  68.7  0.047       9.64
# 4      5                 houston  29.68  119.6   89.9  65.0 -0.011       6.82
# ..   ...                     ...    ...    ...    ...   ...    ...        ...
# 352  353      south carolina st. -25.02   87.1  112.1  71.9 -0.109      -4.54
# 353  354             alabama st. -26.12   84.2  110.3  71.0 -0.049     -14.86
# 354  355  maryland eastern shore -27.33   83.9  111.3  68.0  0.000     -99.00
# 355  356             chicago st. -29.52   88.3  117.8  67.7 -0.006       9.28
# 356  357  mississippi valley st. -41.51   79.2  120.7  71.3  0.040      -4.45
#
#      SOS_OppO  SOS_OppD  NCSOS_AdjEM  TeamID  WTeamID     WScore  AdjEM_x  \
# 0       105.9      98.0         6.34    1211   1211.0  90.733333    36.59
# 1       112.4      94.1         9.99    1228   1228.0  81.250000    30.70
# 356  11.800000  13.000000  24.200000   9.000000  12.600000  6.400000
#
#          LBlk        LPF
# 0    1.900000  19.033333
# 1    2.333333  19.666667
# 2    3.071429  15.428571
# 3    3.736842  18.157895
# 4    2.354839  17.580645
# ..        ...        ...
# 352  2.666667  20.833333
# 353  2.600000  20.000000
# 354  3.200000  19.400000
# 355  0.000000  21.000000
# 356  3.800000  20.400000
#
# [352 rows x 60 columns]

# %%
team_one = full_avg.loc[full_avg['TeamName_Clean'] == 'kentucky']

# %%
#Drop columns not used in regression

team_one = team_one[['AdjEM', 'AdjO', 'AdjD', 'AdjT', 'Luck', 'SOS_AdjEM',
       'SOS_OppO', 'SOS_OppD', 'NCSOS_AdjEM', 'WFGA',
       'WFGA3', 'WFTA', 'WOR', 'WDR', 'WAst', 'WTO', 'WStl', 'WBlk',
       'WPF']]

team_one.head()
# Out:
#     AdjEM   AdjO  AdjD  AdjT   Luck  SOS_AdjEM  SOS_OppO  SOS_OppD  \
# 48  14.97  108.1  93.1  68.3 -0.148      16.65     110.5      93.8
#
#     NCSOS_AdjEM       WFGA      WFGA3       WFTA        WOR        WDR  \
# 48        15.63  55.148148  16.407407  23.111111  11.777778  27.148148
#
#          WAst        WTO      WStl      WBlk        WPF
# 48  13.703704  12.555556  6.555556  5.407407  15.703704

# %%
team_two = full_avg.loc[full_avg['TeamName_Clean'] == 'abilene christian']

# %%
team_two[['AdjEM', 'AdjO', 'AdjD', 'AdjT', 'Luck', 'SOS_AdjEM',
       'SOS_OppO', 'SOS_OppD', 'NCSOS_AdjEM', 'WFGA',
       'WFGA3', 'WFTA', 'WOR', 'WDR', 'WAst', 'WTO', 'WStl', 'WBlk',
       'WPF']]
# Out:
#     AdjEM   AdjO  AdjD  AdjT   Luck  SOS_AdjEM  SOS_OppO  SOS_OppD  \
# 84  10.39  103.3  92.9  69.9 -0.027      -7.74      97.8     105.6
#
#     NCSOS_AdjEM       WFGA      WFGA3       WFTA       WOR        WDR  \
# 84         4.68  55.347826  18.956522  19.608696  9.086957  23.826087
#
#          WAst        WTO  WStl      WBlk        WPF
# 84  15.304348  10.695652   8.0  2.565217  18.695652

# %%
def get_matchup(df, teamA, teamB):
    home = df.loc[df['TeamName_Clean'] == teamA]
    home = home[['AdjEM', 'AdjO', 'AdjD', 'AdjT', 'Luck', 'SOS_AdjEM',
       'SOS_OppO', 'SOS_OppD', 'NCSOS_AdjEM', 'WFGA',
       'WFGA3', 'WFTA', 'WOR', 'WDR', 'WAst', 'WTO', 'WStl', 'WBlk',
       'WPF']]
    
    away = df.loc[df['TeamName_Clean'] == teamB]
    away = away[['AdjEM', 'AdjO', 'AdjD', 'AdjT', 'Luck', 'SOS_AdjEM',
       'SOS_OppO', 'SOS_OppD', 'NCSOS_AdjEM', 'WFGA',
       'WFGA3', 'WFTA', 'WOR', 'WDR', 'WAst', 'WTO', 'WStl', 'WBlk',
       'WPF']]
    
    home_points = pd.merge(home, away, how='outer')
    away_points = pd.merge(away, home, how='outer')
    
    home_points = np.array(home_points).reshape(-1, 38)
    away_points = np.array(away_points).reshape(-1, 38)
    
    home_score = gb.predict(home_points)
    away_score = gb.predict(away_points)
    
    
    return print(f'{teamA}: {round(home_score[0],0)} | {teamB}: {round(away_score[0],0)}')

# %%
get_matchup(full_avg, 'abilene christian', 'kentucky')
# Out:
# abilene christian: 72.0 | kentucky: 70.0

# %%
pd.DataFrame(list(zip(features.columns, gb.feature_importances_))).sort_values(by=1, ascending=False).head(10)
# Out:
#         0         1
# 14   WAst  0.268402
# 9    WFGA  0.258932
# 11   WFTA  0.163380
# 32    LDR  0.126023
# 12    WOR  0.069421
# 28   LFGA  0.040746
# 30   LFTA  0.030306
# 33   LAst  0.013106
# 10  WFGA3  0.011934
# 37    LPF  0.005307
