# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor

# metrics
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# %% [markdown]
# # Data

# %%
# Using Stage 2 because it contains 2021 data

df_massey = pd.read_csv("Data/2021/MDataFiles_Stage2/MMasseyOrdinals.csv")
df_tourney_results = pd.read_csv("Data/2021/MDataFiles_Stage2/MNCAATourneyDetailedResults.csv")
df_season_results = pd.read_csv("Data/2021/MDataFiles_Stage2/MRegularSeasonDetailedResults.csv")
df_teams = pd.read_csv("Data/2021/MDataFiles_Stage2/MTeams.csv")
df_kenPom = pd.read_csv("Data/2021/kenPom.csv")

df_tourney_results.tail()
# Out:
#       Season  DayNum  WTeamID  WScore  LTeamID  LScore WLoc  NumOT  WFGM  \
# 1110    2019     146     1120      77     1246      71    N      1    26
# 1111    2019     146     1277      68     1181      67    N      0    30
# 1112    2019     152     1403      61     1277      51    N      0    22
# 1113    2019     152     1438      63     1120      62    N      0    25
# 1114    2019     154     1438      85     1403      77    N      1    27
#
#       WFGA  ...  LFGA3  LFTM  LFTA  LOR  LDR  LAst  LTO  LStl  LBlk  LPF
# 1110    65  ...     21    12    21   11   30    14   14     5     5   19
# 1111    70  ...     21     8    13   13   29    14   17     4     9    9
# 1112    51  ...     24    14    18    8   28     6   11     1     2   15
# 1113    51  ...     31    11    14    9   24     9    5     3     3   12
# 1114    59  ...     30    13    15    9   23     9    8     6     3   18
#
# [5 rows x 34 columns]

# %%
df_teams
# Out:
#      TeamID      TeamName  FirstD1Season  LastD1Season
# 0      1101   Abilene Chr           2014          2021
# 1      1102     Air Force           1985          2021
# 2      1103         Akron           1985          2021
# 3      1104       Alabama           1985          2021
# 4      1105   Alabama A&M           2000          2021
# ..      ...           ...            ...           ...
# 366    1467     Merrimack           2020          2021
# 367    1468    Bellarmine           2021          2021
# 368    1469      Dixie St           2021          2021
# 369    1470   Tarleton St           2021          2021
# 370    1471  UC San Diego           2021          2021
#
# [371 rows x 4 columns]

# %% [markdown]
# # Data Exploration

# %%
df_massey.tail()
# Out:
#          Season  RankingDayNum SystemName  TeamID  OrdinalRank
# 4339985    2021            133        WOB    1467          233
# 4339986    2021            133        WOB    1468          176
# 4339987    2021            133        WOB    1469          290
# 4339988    2021            133        WOB    1470          256
# 4339989    2021            133        WOB    1471          234

# %%
df_season_results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96687 entries, 0 to 96686
# Data columns (total 34 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Season   96687 non-null  int64
#  1   DayNum   96687 non-null  int64
#  2   WTeamID  96687 non-null  int64
#  3   WScore   96687 non-null  int64
#  4   LTeamID  96687 non-null  int64
#  5   LScore   96687 non-null  int64
#  6   WLoc     96687 non-null  object
#  7   NumOT    96687 non-null  int64
#  8   WFGM     96687 non-null  int64
#  9   WFGA     96687 non-null  int64
#  10  WFGM3    96687 non-null  int64
#  11  WFGA3    96687 non-null  int64
#  12  WFTM     96687 non-null  int64
#  13  WFTA     96687 non-null  int64
#  14  WOR      96687 non-null  int64
#  15  WDR      96687 non-null  int64
#  16  WAst     96687 non-null  int64
#  17  WTO      96687 non-null  int64
#  18  WStl     96687 non-null  int64
#  19  WBlk     96687 non-null  int64
#  20  WPF      96687 non-null  int64
#  21  LFGM     96687 non-null  int64
#  22  LFGA     96687 non-null  int64
#  23  LFGM3    96687 non-null  int64
#  24  LFGA3    96687 non-null  int64
#  25  LFTM     96687 non-null  int64
#  26  LFTA     96687 non-null  int64
#  27  LOR      96687 non-null  int64
#  28  LDR      96687 non-null  int64
#  29  LAst     96687 non-null  int64
#  30  LTO      96687 non-null  int64
#  31  LStl     96687 non-null  int64
#  32  LBlk     96687 non-null  int64
#  33  LPF      96687 non-null  int64
# dtypes: int64(33), object(1)
# memory usage: 25.1+ MB

# %%
# Narrow to 2021 Season

df_2021 = df_season_results.loc[df_season_results.Season == 2021].reset_index(drop=True)
df_massey_2021 = df_massey.loc[df_massey.Season == 2021].reset_index(drop=True)

df_2021
# Out:
#       Season  DayNum  WTeamID  WScore  LTeamID  LScore WLoc  NumOT  WFGM  \
# 0       2021      23     1101      70     1190      47    N      0    20
# 1       2021      23     1104      81     1240      57    H      0    30
# 2       2021      23     1111      81     1354      61    A      0    32
# 3       2021      23     1113      94     1348      88    N      0    27
# 4       2021      23     1114      71     1341      66    N      0    22
# ...      ...     ...      ...     ...      ...     ...  ...    ...   ...
# 3850    2021     132     1104      80     1261      79    N      0    33
# 3851    2021     132     1159      85     1259      72    H      0    31
# 3852    2021     132     1222      91     1153      54    N      0    37
# 3853    2021     132     1228      91     1326      88    N      1    29
# 3854    2021     132     1382      74     1433      65    N      0    25
#
#       WFGA  ...  LFGA3  LFTM  LFTA  LOR  LDR  LAst  LTO  LStl  LBlk  LPF
# 0       49  ...     21    14    17   11   27     5   22     6     2    0
# 1       77  ...     32    10    17   18   28    10   20     5     2    0
# 2       62  ...     32     6    11   12   18    12    9    13     0   14
# 3       61  ...     18    21    35    7   26    14   16     8     2    0
# 4       51  ...     21     4     4    7   15    14   24    12     1    0
# ...    ...  ...    ...   ...   ...  ...  ...   ...  ...   ...   ...  ...
# 3850    76  ...     27     9    13   15   26    10    5     6     5   13
# 3851    59  ...     22     9    16   12   19    12   12     2     1   13
# 3852    66  ...     33    10    15   14   17    11   10     2     5   12
# 3853    64  ...     25    22    30    8   27    11    8     7     4   26
# 3854    62  ...     18    15    20    3   23     9    9     4     4   18
#
# [3855 rows x 34 columns]

# %%
IDs = []
Names = []

for x in range(len(df_teams)):
    ID = df_teams.TeamID[x]
    Name = df_teams.TeamName[x]
    
    IDs.append(ID)
    Names.append(Name)
    
team_zip = zip(IDs, Names)

team_list = []

for TeamID, TeamName in team_zip:
    team_dict = {}
    team_dict['TeamID'] = TeamID
    team_dict['TeamName'] = TeamName
    team_dict['Wins'] = 0
    team_dict['Losses'] = 0
    team_dict['GP'] = 0
    
    team_list.append(team_dict)
    

team_list
# Out:
# [{'TeamID': 1101, 'TeamName': 'Abilene Chr', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1102, 'TeamName': 'Air Force', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1103, 'TeamName': 'Akron', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1104, 'TeamName': 'Alabama', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1105, 'TeamName': 'Alabama A&M', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1106, 'TeamName': 'Alabama St', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1107, 'TeamName': 'SUNY Albany', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1108, 'TeamName': 'Alcorn St', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1109, 'TeamName': 'Alliant Intl', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1110,
#   'TeamName': 'American Univ',
#   'Wins': 0,
#   'Losses': 0,
#   'GP': 0},
#  {'TeamID': 1111,
#   'TeamName': 'Appalachian St',
#   'Wins': 0,
#   'Losses': 0,
#   'GP': 0},
#  {'TeamID': 1112, 'TeamName': 'Arizona', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1113, 'TeamName': 'Arizona St', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1114,
#   'TeamName': 'Ark Little Rock',
#   'Wins': 0,
#   'Losses': 0,
#   'GP': 0},
#  {'TeamID': 1115,
#   'TeamName': 'Ark Pine Bluff',
#   'Wins': 0,
#   'Losses': 0,
#   'GP': 0},
#  {'TeamID': 1116, 'TeamName': 'Arkansas', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1117, 'TeamName': 'Arkansas St', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1118, 'TeamName': 'Armstrong St', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1119, 'TeamName': 'Army', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1120, 'TeamName': 'Auburn', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1121, 'TeamName': 'Augusta', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1122, 'TeamName': 'Austin Peay', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1123, 'TeamName': 'Ball St', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1124, 'TeamName': 'Baylor', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1125, 'TeamName': 'Belmont', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1126,
#   'TeamName': 'Bethune-Cookman',
#   'Wins': 0,
#   'Losses': 0,
#   'GP': 0},
#  {'TeamID': 1127, 'TeamName': 'Binghamton', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1128,
#   'TeamName': 'Birmingham So',
#   'Wins': 0,
#   'Losses': 0,
#   'GP': 0},
#  {'TeamID': 1129, 'TeamName': 'Boise St', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1130,
#   'TeamName': 'Boston College',
#   'Wins': 0,
#   'Losses': 0,
#   'GP': 0},
#  {'TeamID': 1131, 'TeamName': 'Boston Univ', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1132,
#   'TeamName': 'Bowling Green',
#   'Wins': 0,
#   'Losses': 0,
#   'GP': 0},
#  {'TeamID': 1133, 'TeamName': 'Bradley', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1134, 'TeamName': 'Brooklyn', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1135, 'TeamName': 'Brown', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1136, 'TeamName': 'Bryant', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1137, 'TeamName': 'Bucknell', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1138, 'TeamName': 'Buffalo', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1139, 'TeamName': 'Butler', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1140, 'TeamName': 'BYU', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1141, 'TeamName': 'C Michigan', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1142, 'TeamName': 'Cal Poly', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1143, 'TeamName': 'California', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1144, 'TeamName': 'Campbell', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1145, 'TeamName': 'Canisius', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1146,
#   'TeamName': 'Cent Arkansas',
#   'Wins': 0,
#   'Losses': 0,
#   'GP': 0},
#  {'TeamID': 1147, 'TeamName': 'Centenary', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1148, 'TeamName': 'Central Conn', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1149,
#   'TeamName': 'Charleston So',
#   'Wins': 0,
#   'Losses': 0,
#   'GP': 0},
#  {'TeamID': 1150, 'TeamName': 'Charlotte', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1151, 'TeamName': 'Chattanooga', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1152, 'TeamName': 'Chicago St', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1153, 'TeamName': 'Cincinnati', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1154, 'TeamName': 'Citadel', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1155, 'TeamName': 'Clemson', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1156, 'TeamName': 'Cleveland St', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1157, 'TeamName': 'Coastal Car', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1158,
#   'TeamName': 'Col Charleston',
#   'Wins': 0,
#   'Losses': 0,
#   'GP': 0},
#  {'TeamID': 1159, 'TeamName': 'Colgate', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1160, 'TeamName': 'Colorado', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1161, 'TeamName': 'Colorado St', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1162, 'TeamName': 'Columbia', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1163, 'TeamName': 'Connecticut', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1164, 'TeamName': 'Coppin St', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1165, 'TeamName': 'Cornell', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1166, 'TeamName': 'Creighton', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1167,
#   'TeamName': 'CS Bakersfield',
#   'Wins': 0,
#   'Losses': 0,
#   'GP': 0},
#  {'TeamID': 1168, 'TeamName': 'CS Fullerton', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1169,
#   'TeamName': 'CS Northridge',
#   'Wins': 0,
#   'Losses': 0,
#   'GP': 0},
#  {'TeamID': 1170,
#   'TeamName': 'CS Sacramento',
#   'Wins': 0,
#   'Losses': 0,
#   'GP': 0},
#  {'TeamID': 1171, 'TeamName': 'Dartmouth', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1172, 'TeamName': 'Davidson', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1173, 'TeamName': 'Dayton', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1174, 'TeamName': 'Delaware', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1175, 'TeamName': 'Delaware St', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1176, 'TeamName': 'Denver', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1177, 'TeamName': 'DePaul', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1178, 'TeamName': 'Detroit', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1179, 'TeamName': 'Drake', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1180, 'TeamName': 'Drexel', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1181, 'TeamName': 'Duke', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1182, 'TeamName': 'Duquesne', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1183, 'TeamName': 'E Illinois', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1184, 'TeamName': 'E Kentucky', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1185, 'TeamName': 'E Michigan', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1186, 'TeamName': 'E Washington', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1187,
#   'TeamName': 'East Carolina',
#   'Wins': 0,
#   'Losses': 0,
#   'GP': 0},
#  {'TeamID': 1188, 'TeamName': 'SIUE', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1189, 'TeamName': 'Elon', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1190, 'TeamName': 'ETSU', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1191, 'TeamName': 'Evansville', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1192, 'TeamName': 'F Dickinson', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1193, 'TeamName': 'Fairfield', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1194, 'TeamName': 'FL Atlantic', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1195,
#   'TeamName': 'FL Gulf Coast',
#   'Wins': 0,
#   'Losses': 0,
#   'GP': 0},
#  {'TeamID': 1196, 'TeamName': 'Florida', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1197, 'TeamName': 'Florida A&M', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1198, 'TeamName': 'Florida Intl', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1199, 'TeamName': 'Florida St', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1200, 'TeamName': 'Fordham', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1201, 'TeamName': 'Fresno St', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1202, 'TeamName': 'Furman', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1203, 'TeamName': 'G Washington', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1204, 'TeamName': 'Ga Southern', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1205, 'TeamName': 'Gardner Webb', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1206, 'TeamName': 'George Mason', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1207, 'TeamName': 'Georgetown', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1208, 'TeamName': 'Georgia', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1209, 'TeamName': 'Georgia St', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1210, 'TeamName': 'Georgia Tech', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1211, 'TeamName': 'Gonzaga', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1212, 'TeamName': 'Grambling', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1213, 'TeamName': 'Grand Canyon', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1214, 'TeamName': 'Hampton', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1215,
#   'TeamName': 'Hardin-Simmons',
#   'Wins': 0,
#   'Losses': 0,
#   'GP': 0},
#  {'TeamID': 1216, 'TeamName': 'Hartford', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1217, 'TeamName': 'Harvard', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1218, 'TeamName': 'Hawaii', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1219, 'TeamName': 'High Point', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1220, 'TeamName': 'Hofstra', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1221, 'TeamName': 'Holy Cross', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1222, 'TeamName': 'Houston', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1223, 'TeamName': 'Houston Bap', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1224, 'TeamName': 'Howard', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1225, 'TeamName': 'Idaho', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1226, 'TeamName': 'Idaho St', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1227, 'TeamName': 'IL Chicago', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1228, 'TeamName': 'Illinois', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1229, 'TeamName': 'Illinois St', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1230,
#   'TeamName': 'Incarnate Word',
#   'Wins': 0,
#   'Losses': 0,
#   'GP': 0},
#  {'TeamID': 1231, 'TeamName': 'Indiana', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1232, 'TeamName': 'Indiana St', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1233, 'TeamName': 'Iona', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1234, 'TeamName': 'Iowa', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1235, 'TeamName': 'Iowa St', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1236, 'TeamName': 'PFW', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1237, 'TeamName': 'IUPUI', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1238, 'TeamName': 'Jackson St', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1239, 'TeamName': 'Jacksonville', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1240,
#   'TeamName': 'Jacksonville St',
#   'Wins': 0,
#   'Losses': 0,
#   'GP': 0},
#  {'TeamID': 1241,
#   'TeamName': 'James Madison',
#   'Wins': 0,
#   'Losses': 0,
#   'GP': 0},
#  {'TeamID': 1242, 'TeamName': 'Kansas', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1243, 'TeamName': 'Kansas St', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1244, 'TeamName': 'Kennesaw', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1245, 'TeamName': 'Kent', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1246, 'TeamName': 'Kentucky', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1247, 'TeamName': 'La Salle', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1248, 'TeamName': 'Lafayette', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1249, 'TeamName': 'Lamar', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1250, 'TeamName': 'Lehigh', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1251, 'TeamName': 'Liberty', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1252, 'TeamName': 'Lipscomb', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1253,
#   'TeamName': 'Long Beach St',
#   'Wins': 0,
#   'Losses': 0,
#   'GP': 0},
#  {'TeamID': 1254, 'TeamName': 'LIU Brooklyn', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1255, 'TeamName': 'Longwood', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1256,
#   'TeamName': 'Louisiana Tech',
#   'Wins': 0,
#   'Losses': 0,
#   'GP': 0},
#  {'TeamID': 1257, 'TeamName': 'Louisville', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1258,
#   'TeamName': 'Loy Marymount',
#   'Wins': 0,
#   'Losses': 0,
#   'GP': 0},
#  {'TeamID': 1259, 'TeamName': 'Loyola MD', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1260,
#   'TeamName': 'Loyola-Chicago',
#   'Wins': 0,
#   'Losses': 0,
#   'GP': 0},
#  {'TeamID': 1261, 'TeamName': 'LSU', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1262, 'TeamName': 'MA Lowell', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1263, 'TeamName': 'Maine', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1264, 'TeamName': 'Manhattan', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1265, 'TeamName': 'Marist', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1266, 'TeamName': 'Marquette', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1267, 'TeamName': 'Marshall', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1268, 'TeamName': 'Maryland', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1269,
#   'TeamName': 'Massachusetts',
#   'Wins': 0,
#   'Losses': 0,
#   'GP': 0},
#  {'TeamID': 1270, 'TeamName': 'McNeese St', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1271, 'TeamName': 'MD E Shore', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1272, 'TeamName': 'Memphis', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1273, 'TeamName': 'Mercer', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1274, 'TeamName': 'Miami FL', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1275, 'TeamName': 'Miami OH', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1276, 'TeamName': 'Michigan', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1277, 'TeamName': 'Michigan St', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1278, 'TeamName': 'Minnesota', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1279, 'TeamName': 'Mississippi', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1280,
#   'TeamName': 'Mississippi St',
#   'Wins': 0,
#   'Losses': 0,
#   'GP': 0},
#  {'TeamID': 1281, 'TeamName': 'Missouri', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1282, 'TeamName': 'Missouri KC', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1283, 'TeamName': 'Missouri St', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1284, 'TeamName': 'Monmouth NJ', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1285, 'TeamName': 'Montana', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1286, 'TeamName': 'Montana St', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1287, 'TeamName': 'Morehead St', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1288, 'TeamName': 'Morgan St', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1289, 'TeamName': 'Morris Brown', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1290, 'TeamName': 'MS Valley St', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1291, 'TeamName': "Mt St Mary's", 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1292, 'TeamName': 'MTSU', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1293, 'TeamName': 'Murray St', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1294, 'TeamName': 'N Colorado', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1295, 'TeamName': 'N Dakota St', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1296, 'TeamName': 'N Illinois', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1297, 'TeamName': 'N Kentucky', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1298, 'TeamName': 'Navy', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1299, 'TeamName': 'NC A&T', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1300, 'TeamName': 'NC Central', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1301, 'TeamName': 'NC State', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1302, 'TeamName': 'NE Illinois', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1303, 'TeamName': 'NE Omaha', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1304, 'TeamName': 'Nebraska', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1305, 'TeamName': 'Nevada', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1306,
#   'TeamName': 'New Hampshire',
#   'Wins': 0,
#   'Losses': 0,
#   'GP': 0},
#  {'TeamID': 1307, 'TeamName': 'New Mexico', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1308,
#   'TeamName': 'New Mexico St',
#   'Wins': 0,
#   'Losses': 0,
#   'GP': 0},
#  {'TeamID': 1309, 'TeamName': 'New Orleans', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1310, 'TeamName': 'Niagara', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1311, 'TeamName': 'Nicholls St', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1312, 'TeamName': 'NJIT', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1313, 'TeamName': 'Norfolk St', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1314,
#   'TeamName': 'North Carolina',
#   'Wins': 0,
#   'Losses': 0,
#   'GP': 0},
#  {'TeamID': 1315, 'TeamName': 'North Dakota', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1316,
#   'TeamName': 'North Florida',
#   'Wins': 0,
#   'Losses': 0,
#   'GP': 0},
#  {'TeamID': 1317, 'TeamName': 'North Texas', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1318, 'TeamName': 'Northeastern', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1319,
#   'TeamName': 'Northern Arizona',
#   'Wins': 0,
#   'Losses': 0,
#   'GP': 0},
#  {'TeamID': 1320,
#   'TeamName': 'Northern Iowa',
#   'Wins': 0,
#   'Losses': 0,
#   'GP': 0},
#  {'TeamID': 1321, 'TeamName': 'Northwestern', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1322,
#   'TeamName': 'Northwestern LA',
#   'Wins': 0,
#   'Losses': 0,
#   'GP': 0},
#  {'TeamID': 1323, 'TeamName': 'Notre Dame', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1324, 'TeamName': 'Oakland', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1325, 'TeamName': 'Ohio', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1326, 'TeamName': 'Ohio St', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1327, 'TeamName': 'Okla City', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1328, 'TeamName': 'Oklahoma', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1329, 'TeamName': 'Oklahoma St', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1330, 'TeamName': 'Old Dominion', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1331, 'TeamName': 'Oral Roberts', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1332, 'TeamName': 'Oregon', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1333, 'TeamName': 'Oregon St', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1334, 'TeamName': 'Pacific', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1335, 'TeamName': 'Penn', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1336, 'TeamName': 'Penn St', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1337, 'TeamName': 'Pepperdine', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1338, 'TeamName': 'Pittsburgh', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1339, 'TeamName': 'Portland', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1340, 'TeamName': 'Portland St', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1341, 'TeamName': 'Prairie View', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1342, 'TeamName': 'Presbyterian', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1343, 'TeamName': 'Princeton', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1344, 'TeamName': 'Providence', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1345, 'TeamName': 'Purdue', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1346, 'TeamName': 'Quinnipiac', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1347, 'TeamName': 'Radford', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1348, 'TeamName': 'Rhode Island', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1349, 'TeamName': 'Rice', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1350, 'TeamName': 'Richmond', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1351, 'TeamName': 'Rider', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1352,
#   'TeamName': 'Robert Morris',
#   'Wins': 0,
#   'Losses': 0,
#   'GP': 0},
#  {'TeamID': 1353, 'TeamName': 'Rutgers', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1354,
#   'TeamName': 'S Carolina St',
#   'Wins': 0,
#   'Losses': 0,
#   'GP': 0},
#  {'TeamID': 1355, 'TeamName': 'S Dakota St', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1356, 'TeamName': 'S Illinois', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1357, 'TeamName': 'Sacred Heart', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1358,
#   'TeamName': 'Sam Houston St',
#   'Wins': 0,
#   'Losses': 0,
#   'GP': 0},
#  {'TeamID': 1359, 'TeamName': 'Samford', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1360, 'TeamName': 'San Diego', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1361, 'TeamName': 'San Diego St', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1362,
#   'TeamName': 'San Francisco',
#   'Wins': 0,
#   'Losses': 0,
#   'GP': 0},
#  {'TeamID': 1363, 'TeamName': 'San Jose St', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1364,
#   'TeamName': 'UC Santa Barbara',
#   'Wins': 0,
#   'Losses': 0,
#   'GP': 0},
#  {'TeamID': 1365, 'TeamName': 'Santa Clara', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1366, 'TeamName': 'Savannah St', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1367, 'TeamName': 'SC Upstate', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1368, 'TeamName': 'SE Louisiana', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1369,
#   'TeamName': 'SE Missouri St',
#   'Wins': 0,
#   'Losses': 0,
#   'GP': 0},
#  {'TeamID': 1370, 'TeamName': 'Seattle', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1371, 'TeamName': 'Seton Hall', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1372, 'TeamName': 'SF Austin', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1373, 'TeamName': 'Siena', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1374, 'TeamName': 'SMU', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1375,
#   'TeamName': 'South Alabama',
#   'Wins': 0,
#   'Losses': 0,
#   'GP': 0},
#  {'TeamID': 1376,
#   'TeamName': 'South Carolina',
#   'Wins': 0,
#   'Losses': 0,
#   'GP': 0},
#  {'TeamID': 1377, 'TeamName': 'South Dakota', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1378,
#   'TeamName': 'South Florida',
#   'Wins': 0,
#   'Losses': 0,
#   'GP': 0},
#  {'TeamID': 1379,
#   'TeamName': 'Southern Miss',
#   'Wins': 0,
#   'Losses': 0,
#   'GP': 0},
#  {'TeamID': 1380,
#   'TeamName': 'Southern Univ',
#   'Wins': 0,
#   'Losses': 0,
#   'GP': 0},
#  {'TeamID': 1381,
#   'TeamName': 'Southern Utah',
#   'Wins': 0,
#   'Losses': 0,
#   'GP': 0},
#  {'TeamID': 1382,
#   'TeamName': 'St Bonaventure',
#   'Wins': 0,
#   'Losses': 0,
#   'GP': 0},
#  {'TeamID': 1383,
#   'TeamName': 'St Francis NY',
#   'Wins': 0,
#   'Losses': 0,
#   'GP': 0},
#  {'TeamID': 1384,
#   'TeamName': 'St Francis PA',
#   'Wins': 0,
#   'Losses': 0,
#   'GP': 0},
#  {'TeamID': 1385, 'TeamName': "St John's", 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1386,
#   'TeamName': "St Joseph's PA",
#   'Wins': 0,
#   'Losses': 0,
#   'GP': 0},
#  {'TeamID': 1387, 'TeamName': 'St Louis', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1388, 'TeamName': "St Mary's CA", 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1389, 'TeamName': "St Peter's", 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1390, 'TeamName': 'Stanford', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1391, 'TeamName': 'Stetson', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1392, 'TeamName': 'Stony Brook', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1393, 'TeamName': 'Syracuse', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1394,
#   'TeamName': 'TAM C. Christi',
#   'Wins': 0,
#   'Losses': 0,
#   'GP': 0},
#  {'TeamID': 1395, 'TeamName': 'TCU', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1396, 'TeamName': 'Temple', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1397, 'TeamName': 'Tennessee', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1398, 'TeamName': 'Tennessee St', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1399,
#   'TeamName': 'Tennessee Tech',
#   'Wins': 0,
#   'Losses': 0,
#   'GP': 0},
#  {'TeamID': 1400, 'TeamName': 'Texas', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1401, 'TeamName': 'Texas A&M', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1402, 'TeamName': 'Texas St', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1403, 'TeamName': 'Texas Tech', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1404, 'TeamName': 'TN Martin', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1405, 'TeamName': 'Toledo', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1406, 'TeamName': 'Towson', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1407, 'TeamName': 'Troy', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1408, 'TeamName': 'Tulane', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1409, 'TeamName': 'Tulsa', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1410, 'TeamName': 'UTRGV', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1411, 'TeamName': 'TX Southern', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1412, 'TeamName': 'UAB', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1413, 'TeamName': 'UC Davis', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1414, 'TeamName': 'UC Irvine', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1415, 'TeamName': 'UC Riverside', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1416, 'TeamName': 'UCF', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1417, 'TeamName': 'UCLA', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1418, 'TeamName': 'Louisiana', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1419, 'TeamName': 'ULM', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1420, 'TeamName': 'UMBC', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1421,
#   'TeamName': 'UNC Asheville',
#   'Wins': 0,
#   'Losses': 0,
#   'GP': 0},
#  {'TeamID': 1422,
#   'TeamName': 'UNC Greensboro',
#   'Wins': 0,
#   'Losses': 0,
#   'GP': 0},
#  {'TeamID': 1423,
#   'TeamName': 'UNC Wilmington',
#   'Wins': 0,
#   'Losses': 0,
#   'GP': 0},
#  {'TeamID': 1424, 'TeamName': 'UNLV', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1425, 'TeamName': 'USC', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1426, 'TeamName': 'UT Arlington', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1427,
#   'TeamName': 'UT San Antonio',
#   'Wins': 0,
#   'Losses': 0,
#   'GP': 0},
#  {'TeamID': 1428, 'TeamName': 'Utah', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1429, 'TeamName': 'Utah St', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1430, 'TeamName': 'Utah Valley', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1431, 'TeamName': 'UTEP', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1432, 'TeamName': 'Utica', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1433, 'TeamName': 'VCU', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1434, 'TeamName': 'Valparaiso', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1435, 'TeamName': 'Vanderbilt', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1436, 'TeamName': 'Vermont', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1437, 'TeamName': 'Villanova', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1438, 'TeamName': 'Virginia', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1439,
#   'TeamName': 'Virginia Tech',
#   'Wins': 0,
#   'Losses': 0,
#   'GP': 0},
#  {'TeamID': 1440, 'TeamName': 'VMI', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1441, 'TeamName': 'W Carolina', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1442, 'TeamName': 'W Illinois', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1443, 'TeamName': 'WKU', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1444, 'TeamName': 'W Michigan', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1445, 'TeamName': 'W Salem St', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1446, 'TeamName': 'W Texas A&M', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1447, 'TeamName': 'Wagner', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1448, 'TeamName': 'Wake Forest', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1449, 'TeamName': 'Washington', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1450,
#   'TeamName': 'Washington St',
#   'Wins': 0,
#   'Losses': 0,
#   'GP': 0},
#  {'TeamID': 1451, 'TeamName': 'Weber St', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1452,
#   'TeamName': 'West Virginia',
#   'Wins': 0,
#   'Losses': 0,
#   'GP': 0},
#  {'TeamID': 1453, 'TeamName': 'WI Green Bay', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1454, 'TeamName': 'WI Milwaukee', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1455, 'TeamName': 'Wichita St', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1456,
#   'TeamName': 'William & Mary',
#   'Wins': 0,
#   'Losses': 0,
#   'GP': 0},
#  {'TeamID': 1457, 'TeamName': 'Winthrop', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1458, 'TeamName': 'Wisconsin', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1459, 'TeamName': 'Wofford', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1460, 'TeamName': 'Wright St', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1461, 'TeamName': 'Wyoming', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1462, 'TeamName': 'Xavier', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1463, 'TeamName': 'Yale', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1464,
#   'TeamName': 'Youngstown St',
#   'Wins': 0,
#   'Losses': 0,
#   'GP': 0},
#  {'TeamID': 1465, 'TeamName': 'Cal Baptist', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1466,
#   'TeamName': 'North Alabama',
#   'Wins': 0,
#   'Losses': 0,
#   'GP': 0},
#  {'TeamID': 1467, 'TeamName': 'Merrimack', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1468, 'TeamName': 'Bellarmine', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1469, 'TeamName': 'Dixie St', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1470, 'TeamName': 'Tarleton St', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1471, 'TeamName': 'UC San Diego', 'Wins': 0, 'Losses': 0, 'GP': 0}]

# %%
winning_teams = []
losing_teams = []


for index, row in df_2021.iterrows():
    win = row.WTeamID
    loss = row.LTeamID
    for team in team_list:
        if team['TeamID'] == win:
            winning_teams.append(team['TeamName'])
            team['Wins'] += 1
            team['GP'] += 1
        elif team['TeamID'] == loss:
            losing_teams.append(team['TeamName'])
            team['Losses'] += 1
            team['GP'] +=1
        else:
            pass
        
team_list
# Out:
# [{'TeamID': 1101,
#   'TeamName': 'Abilene Chr',
#   'Wins': 19,
#   'Losses': 4,
#   'GP': 23},
#  {'TeamID': 1102, 'TeamName': 'Air Force', 'Wins': 5, 'Losses': 20, 'GP': 25},
#  {'TeamID': 1103, 'TeamName': 'Akron', 'Wins': 13, 'Losses': 8, 'GP': 21},
#  {'TeamID': 1104, 'TeamName': 'Alabama', 'Wins': 24, 'Losses': 6, 'GP': 30},
#  {'TeamID': 1105, 'TeamName': 'Alabama A&M', 'Wins': 6, 'Losses': 9, 'GP': 15},
#  {'TeamID': 1106, 'TeamName': 'Alabama St', 'Wins': 4, 'Losses': 14, 'GP': 18},
#  {'TeamID': 1107, 'TeamName': 'SUNY Albany', 'Wins': 7, 'Losses': 9, 'GP': 16},
#  {'TeamID': 1108, 'TeamName': 'Alcorn St', 'Wins': 6, 'Losses': 13, 'GP': 19},
#  {'TeamID': 1109, 'TeamName': 'Alliant Intl', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1110,
#   'TeamName': 'American Univ',
#   'Wins': 4,
#   'Losses': 6,
#   'GP': 10},
#  {'TeamID': 1111,
#   'TeamName': 'Appalachian St',
#   'Wins': 13,
#   'Losses': 11,
#   'GP': 24},
#  {'TeamID': 1112, 'TeamName': 'Arizona', 'Wins': 17, 'Losses': 9, 'GP': 26},
#  {'TeamID': 1113,
#   'TeamName': 'Arizona St',
#   'Wins': 11,
#   'Losses': 14,
#   'GP': 25},
#  {'TeamID': 1114,
#   'TeamName': 'Ark Little Rock',
#   'Wins': 10,
#   'Losses': 15,
#   'GP': 25},
#  {'TeamID': 1115,
#   'TeamName': 'Ark Pine Bluff',
#   'Wins': 4,
#   'Losses': 21,
#   'GP': 25},
#  {'TeamID': 1116, 'TeamName': 'Arkansas', 'Wins': 22, 'Losses': 6, 'GP': 28},
#  {'TeamID': 1117,
#   'TeamName': 'Arkansas St',
#   'Wins': 8,
#   'Losses': 13,
#   'GP': 21},
#  {'TeamID': 1118, 'TeamName': 'Armstrong St', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1119, 'TeamName': 'Army', 'Wins': 11, 'Losses': 9, 'GP': 20},
#  {'TeamID': 1120, 'TeamName': 'Auburn', 'Wins': 13, 'Losses': 14, 'GP': 27},
#  {'TeamID': 1121, 'TeamName': 'Augusta', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1122,
#   'TeamName': 'Austin Peay',
#   'Wins': 12,
#   'Losses': 13,
#   'GP': 25},
#  {'TeamID': 1123, 'TeamName': 'Ball St', 'Wins': 10, 'Losses': 13, 'GP': 23},
#  {'TeamID': 1124, 'TeamName': 'Baylor', 'Wins': 22, 'Losses': 2, 'GP': 24},
#  {'TeamID': 1125, 'TeamName': 'Belmont', 'Wins': 25, 'Losses': 4, 'GP': 29},
#  {'TeamID': 1126,
#   'TeamName': 'Bethune-Cookman',
#   'Wins': 0,
#   'Losses': 0,
#   'GP': 0},
#  {'TeamID': 1127, 'TeamName': 'Binghamton', 'Wins': 4, 'Losses': 14, 'GP': 18},
#  {'TeamID': 1128,
#   'TeamName': 'Birmingham So',
#   'Wins': 0,
#   'Losses': 0,
#   'GP': 0},
#  {'TeamID': 1129, 'TeamName': 'Boise St', 'Wins': 17, 'Losses': 8, 'GP': 25},
#  {'TeamID': 1130,
#   'TeamName': 'Boston College',
#   'Wins': 4,
#   'Losses': 16,
#   'GP': 20},
#  {'TeamID': 1131,
#   'TeamName': 'Boston Univ',
#   'Wins': 7,
#   'Losses': 11,
#   'GP': 18},
#  {'TeamID': 1132,
#   'TeamName': 'Bowling Green',
#   'Wins': 13,
#   'Losses': 11,
#   'GP': 24},
#  {'TeamID': 1133, 'TeamName': 'Bradley', 'Wins': 10, 'Losses': 16, 'GP': 26},
#  {'TeamID': 1134, 'TeamName': 'Brooklyn', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1135, 'TeamName': 'Brown', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1136, 'TeamName': 'Bryant', 'Wins': 14, 'Losses': 6, 'GP': 20},
#  {'TeamID': 1137, 'TeamName': 'Bucknell', 'Wins': 5, 'Losses': 7, 'GP': 12},
#  {'TeamID': 1138, 'TeamName': 'Buffalo', 'Wins': 15, 'Losses': 8, 'GP': 23},
#  {'TeamID': 1139, 'TeamName': 'Butler', 'Wins': 10, 'Losses': 15, 'GP': 25},
#  {'TeamID': 1140, 'TeamName': 'BYU', 'Wins': 19, 'Losses': 6, 'GP': 25},
#  {'TeamID': 1141, 'TeamName': 'C Michigan', 'Wins': 5, 'Losses': 15, 'GP': 20},
#  {'TeamID': 1142, 'TeamName': 'Cal Poly', 'Wins': 3, 'Losses': 20, 'GP': 23},
#  {'TeamID': 1143, 'TeamName': 'California', 'Wins': 8, 'Losses': 20, 'GP': 28},
#  {'TeamID': 1144, 'TeamName': 'Campbell', 'Wins': 15, 'Losses': 10, 'GP': 25},
#  {'TeamID': 1145, 'TeamName': 'Canisius', 'Wins': 7, 'Losses': 6, 'GP': 13},
#  {'TeamID': 1146,
#   'TeamName': 'Cent Arkansas',
#   'Wins': 4,
#   'Losses': 19,
#   'GP': 23},
#  {'TeamID': 1147, 'TeamName': 'Centenary', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1148,
#   'TeamName': 'Central Conn',
#   'Wins': 5,
#   'Losses': 16,
#   'GP': 21},
#  {'TeamID': 1149,
#   'TeamName': 'Charleston So',
#   'Wins': 2,
#   'Losses': 18,
#   'GP': 20},
#  {'TeamID': 1150, 'TeamName': 'Charlotte', 'Wins': 9, 'Losses': 15, 'GP': 24},
#  {'TeamID': 1151,
#   'TeamName': 'Chattanooga',
#   'Wins': 16,
#   'Losses': 8,
#   'GP': 24},
#  {'TeamID': 1152, 'TeamName': 'Chicago St', 'Wins': 0, 'Losses': 9, 'GP': 9},
#  {'TeamID': 1153,
#   'TeamName': 'Cincinnati',
#   'Wins': 12,
#   'Losses': 11,
#   'GP': 23},
#  {'TeamID': 1154, 'TeamName': 'Citadel', 'Wins': 9, 'Losses': 12, 'GP': 21},
#  {'TeamID': 1155, 'TeamName': 'Clemson', 'Wins': 16, 'Losses': 7, 'GP': 23},
#  {'TeamID': 1156,
#   'TeamName': 'Cleveland St',
#   'Wins': 19,
#   'Losses': 7,
#   'GP': 26},
#  {'TeamID': 1157,
#   'TeamName': 'Coastal Car',
#   'Wins': 12,
#   'Losses': 7,
#   'GP': 19},
#  {'TeamID': 1158,
#   'TeamName': 'Col Charleston',
#   'Wins': 7,
#   'Losses': 10,
#   'GP': 17},
#  {'TeamID': 1159, 'TeamName': 'Colgate', 'Wins': 14, 'Losses': 1, 'GP': 15},
#  {'TeamID': 1160, 'TeamName': 'Colorado', 'Wins': 22, 'Losses': 8, 'GP': 30},
#  {'TeamID': 1161,
#   'TeamName': 'Colorado St',
#   'Wins': 17,
#   'Losses': 6,
#   'GP': 23},
#  {'TeamID': 1162, 'TeamName': 'Columbia', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1163,
#   'TeamName': 'Connecticut',
#   'Wins': 15,
#   'Losses': 7,
#   'GP': 22},
#  {'TeamID': 1164, 'TeamName': 'Coppin St', 'Wins': 9, 'Losses': 13, 'GP': 22},
#  {'TeamID': 1165, 'TeamName': 'Cornell', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1166, 'TeamName': 'Creighton', 'Wins': 20, 'Losses': 8, 'GP': 28},
#  {'TeamID': 1167,
#   'TeamName': 'CS Bakersfield',
#   'Wins': 13,
#   'Losses': 11,
#   'GP': 24},
#  {'TeamID': 1168,
#   'TeamName': 'CS Fullerton',
#   'Wins': 5,
#   'Losses': 10,
#   'GP': 15},
#  {'TeamID': 1169,
#   'TeamName': 'CS Northridge',
#   'Wins': 8,
#   'Losses': 13,
#   'GP': 21},
#  {'TeamID': 1170,
#   'TeamName': 'CS Sacramento',
#   'Wins': 6,
#   'Losses': 12,
#   'GP': 18},
#  {'TeamID': 1171, 'TeamName': 'Dartmouth', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1172, 'TeamName': 'Davidson', 'Wins': 12, 'Losses': 8, 'GP': 20},
#  {'TeamID': 1173, 'TeamName': 'Dayton', 'Wins': 14, 'Losses': 9, 'GP': 23},
#  {'TeamID': 1174, 'TeamName': 'Delaware', 'Wins': 6, 'Losses': 8, 'GP': 14},
#  {'TeamID': 1175,
#   'TeamName': 'Delaware St',
#   'Wins': 1,
#   'Losses': 16,
#   'GP': 17},
#  {'TeamID': 1176, 'TeamName': 'Denver', 'Wins': 1, 'Losses': 19, 'GP': 20},
#  {'TeamID': 1177, 'TeamName': 'DePaul', 'Wins': 5, 'Losses': 14, 'GP': 19},
#  {'TeamID': 1178, 'TeamName': 'Detroit', 'Wins': 12, 'Losses': 10, 'GP': 22},
#  {'TeamID': 1179, 'TeamName': 'Drake', 'Wins': 23, 'Losses': 4, 'GP': 27},
#  {'TeamID': 1180, 'TeamName': 'Drexel', 'Wins': 12, 'Losses': 7, 'GP': 19},
#  {'TeamID': 1181, 'TeamName': 'Duke', 'Wins': 13, 'Losses': 11, 'GP': 24},
#  {'TeamID': 1182, 'TeamName': 'Duquesne', 'Wins': 9, 'Losses': 9, 'GP': 18},
#  {'TeamID': 1183, 'TeamName': 'E Illinois', 'Wins': 9, 'Losses': 18, 'GP': 27},
#  {'TeamID': 1184, 'TeamName': 'E Kentucky', 'Wins': 20, 'Losses': 7, 'GP': 27},
#  {'TeamID': 1185, 'TeamName': 'E Michigan', 'Wins': 3, 'Losses': 12, 'GP': 15},
#  {'TeamID': 1186,
#   'TeamName': 'E Washington',
#   'Wins': 15,
#   'Losses': 7,
#   'GP': 22},
#  {'TeamID': 1187,
#   'TeamName': 'East Carolina',
#   'Wins': 7,
#   'Losses': 11,
#   'GP': 18},
#  {'TeamID': 1188, 'TeamName': 'SIUE', 'Wins': 8, 'Losses': 17, 'GP': 25},
#  {'TeamID': 1189, 'TeamName': 'Elon', 'Wins': 9, 'Losses': 9, 'GP': 18},
#  {'TeamID': 1190, 'TeamName': 'ETSU', 'Wins': 11, 'Losses': 12, 'GP': 23},
#  {'TeamID': 1191, 'TeamName': 'Evansville', 'Wins': 9, 'Losses': 16, 'GP': 25},
#  {'TeamID': 1192,
#   'TeamName': 'F Dickinson',
#   'Wins': 9,
#   'Losses': 15,
#   'GP': 24},
#  {'TeamID': 1193, 'TeamName': 'Fairfield', 'Wins': 10, 'Losses': 17, 'GP': 27},
#  {'TeamID': 1194,
#   'TeamName': 'FL Atlantic',
#   'Wins': 9,
#   'Losses': 10,
#   'GP': 19},
#  {'TeamID': 1195,
#   'TeamName': 'FL Gulf Coast',
#   'Wins': 8,
#   'Losses': 8,
#   'GP': 16},
#  {'TeamID': 1196, 'TeamName': 'Florida', 'Wins': 14, 'Losses': 9, 'GP': 23},
#  {'TeamID': 1197,
#   'TeamName': 'Florida A&M',
#   'Wins': 8,
#   'Losses': 12,
#   'GP': 20},
#  {'TeamID': 1198,
#   'TeamName': 'Florida Intl',
#   'Wins': 5,
#   'Losses': 17,
#   'GP': 22},
#  {'TeamID': 1199, 'TeamName': 'Florida St', 'Wins': 16, 'Losses': 6, 'GP': 22},
#  {'TeamID': 1200, 'TeamName': 'Fordham', 'Wins': 2, 'Losses': 12, 'GP': 14},
#  {'TeamID': 1201, 'TeamName': 'Fresno St', 'Wins': 10, 'Losses': 12, 'GP': 22},
#  {'TeamID': 1202, 'TeamName': 'Furman', 'Wins': 13, 'Losses': 9, 'GP': 22},
#  {'TeamID': 1203,
#   'TeamName': 'G Washington',
#   'Wins': 5,
#   'Losses': 12,
#   'GP': 17},
#  {'TeamID': 1204,
#   'TeamName': 'Ga Southern',
#   'Wins': 9,
#   'Losses': 13,
#   'GP': 22},
#  {'TeamID': 1205,
#   'TeamName': 'Gardner Webb',
#   'Wins': 11,
#   'Losses': 15,
#   'GP': 26},
#  {'TeamID': 1206,
#   'TeamName': 'George Mason',
#   'Wins': 12,
#   'Losses': 9,
#   'GP': 21},
#  {'TeamID': 1207,
#   'TeamName': 'Georgetown',
#   'Wins': 13,
#   'Losses': 12,
#   'GP': 25},
#  {'TeamID': 1208, 'TeamName': 'Georgia', 'Wins': 13, 'Losses': 12, 'GP': 25},
#  {'TeamID': 1209, 'TeamName': 'Georgia St', 'Wins': 14, 'Losses': 6, 'GP': 20},
#  {'TeamID': 1210,
#   'TeamName': 'Georgia Tech',
#   'Wins': 17,
#   'Losses': 8,
#   'GP': 25},
#  {'TeamID': 1211, 'TeamName': 'Gonzaga', 'Wins': 26, 'Losses': 0, 'GP': 26},
#  {'TeamID': 1212, 'TeamName': 'Grambling', 'Wins': 11, 'Losses': 12, 'GP': 23},
#  {'TeamID': 1213,
#   'TeamName': 'Grand Canyon',
#   'Wins': 14,
#   'Losses': 6,
#   'GP': 20},
#  {'TeamID': 1214, 'TeamName': 'Hampton', 'Wins': 11, 'Losses': 14, 'GP': 25},
#  {'TeamID': 1215,
#   'TeamName': 'Hardin-Simmons',
#   'Wins': 0,
#   'Losses': 0,
#   'GP': 0},
#  {'TeamID': 1216, 'TeamName': 'Hartford', 'Wins': 15, 'Losses': 8, 'GP': 23},
#  {'TeamID': 1217, 'TeamName': 'Harvard', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1218, 'TeamName': 'Hawaii', 'Wins': 9, 'Losses': 10, 'GP': 19},
#  {'TeamID': 1219, 'TeamName': 'High Point', 'Wins': 9, 'Losses': 15, 'GP': 24},
#  {'TeamID': 1220, 'TeamName': 'Hofstra', 'Wins': 13, 'Losses': 10, 'GP': 23},
#  {'TeamID': 1221, 'TeamName': 'Holy Cross', 'Wins': 5, 'Losses': 11, 'GP': 16},
#  {'TeamID': 1222, 'TeamName': 'Houston', 'Wins': 23, 'Losses': 3, 'GP': 26},
#  {'TeamID': 1223,
#   'TeamName': 'Houston Bap',
#   'Wins': 5,
#   'Losses': 19,
#   'GP': 24},
#  {'TeamID': 1224, 'TeamName': 'Howard', 'Wins': 1, 'Losses': 3, 'GP': 4},
#  {'TeamID': 1225, 'TeamName': 'Idaho', 'Wins': 1, 'Losses': 21, 'GP': 22},
#  {'TeamID': 1226, 'TeamName': 'Idaho St', 'Wins': 8, 'Losses': 11, 'GP': 19},
#  {'TeamID': 1227, 'TeamName': 'IL Chicago', 'Wins': 9, 'Losses': 13, 'GP': 22},
#  {'TeamID': 1228, 'TeamName': 'Illinois', 'Wins': 23, 'Losses': 6, 'GP': 29},
#  {'TeamID': 1229,
#   'TeamName': 'Illinois St',
#   'Wins': 6,
#   'Losses': 18,
#   'GP': 24},
#  {'TeamID': 1230,
#   'TeamName': 'Incarnate Word',
#   'Wins': 5,
#   'Losses': 14,
#   'GP': 19},
#  {'TeamID': 1231, 'TeamName': 'Indiana', 'Wins': 12, 'Losses': 15, 'GP': 27},
#  {'TeamID': 1232,
#   'TeamName': 'Indiana St',
#   'Wins': 14,
#   'Losses': 10,
#   'GP': 24},
#  {'TeamID': 1233, 'TeamName': 'Iona', 'Wins': 12, 'Losses': 5, 'GP': 17},
#  {'TeamID': 1234, 'TeamName': 'Iowa', 'Wins': 21, 'Losses': 8, 'GP': 29},
#  {'TeamID': 1235, 'TeamName': 'Iowa St', 'Wins': 2, 'Losses': 22, 'GP': 24},
#  {'TeamID': 1236, 'TeamName': 'PFW', 'Wins': 8, 'Losses': 15, 'GP': 23},
#  {'TeamID': 1237, 'TeamName': 'IUPUI', 'Wins': 8, 'Losses': 10, 'GP': 18},
#  {'TeamID': 1238, 'TeamName': 'Jackson St', 'Wins': 12, 'Losses': 6, 'GP': 18},
#  {'TeamID': 1239,
#   'TeamName': 'Jacksonville',
#   'Wins': 9,
#   'Losses': 13,
#   'GP': 22},
#  {'TeamID': 1240,
#   'TeamName': 'Jacksonville St',
#   'Wins': 16,
#   'Losses': 9,
#   'GP': 25},
#  {'TeamID': 1241,
#   'TeamName': 'James Madison',
#   'Wins': 10,
#   'Losses': 7,
#   'GP': 17},
#  {'TeamID': 1242, 'TeamName': 'Kansas', 'Wins': 19, 'Losses': 8, 'GP': 27},
#  {'TeamID': 1243, 'TeamName': 'Kansas St', 'Wins': 9, 'Losses': 19, 'GP': 28},
#  {'TeamID': 1244, 'TeamName': 'Kennesaw', 'Wins': 2, 'Losses': 19, 'GP': 21},
#  {'TeamID': 1245, 'TeamName': 'Kent', 'Wins': 14, 'Losses': 8, 'GP': 22},
#  {'TeamID': 1246, 'TeamName': 'Kentucky', 'Wins': 9, 'Losses': 16, 'GP': 25},
#  {'TeamID': 1247, 'TeamName': 'La Salle', 'Wins': 8, 'Losses': 16, 'GP': 24},
#  {'TeamID': 1248, 'TeamName': 'Lafayette', 'Wins': 9, 'Losses': 6, 'GP': 15},
#  {'TeamID': 1249, 'TeamName': 'Lamar', 'Wins': 10, 'Losses': 18, 'GP': 28},
#  {'TeamID': 1250, 'TeamName': 'Lehigh', 'Wins': 4, 'Losses': 11, 'GP': 15},
#  {'TeamID': 1251, 'TeamName': 'Liberty', 'Wins': 19, 'Losses': 5, 'GP': 24},
#  {'TeamID': 1252, 'TeamName': 'Lipscomb', 'Wins': 11, 'Losses': 12, 'GP': 23},
#  {'TeamID': 1253,
#   'TeamName': 'Long Beach St',
#   'Wins': 6,
#   'Losses': 12,
#   'GP': 18},
#  {'TeamID': 1254,
#   'TeamName': 'LIU Brooklyn',
#   'Wins': 9,
#   'Losses': 9,
#   'GP': 18},
#  {'TeamID': 1255, 'TeamName': 'Longwood', 'Wins': 12, 'Losses': 15, 'GP': 27},
#  {'TeamID': 1256,
#   'TeamName': 'Louisiana Tech',
#   'Wins': 20,
#   'Losses': 7,
#   'GP': 27},
#  {'TeamID': 1257, 'TeamName': 'Louisville', 'Wins': 13, 'Losses': 7, 'GP': 20},
#  {'TeamID': 1258,
#   'TeamName': 'Loy Marymount',
#   'Wins': 13,
#   'Losses': 9,
#   'GP': 22},
#  {'TeamID': 1259, 'TeamName': 'Loyola MD', 'Wins': 6, 'Losses': 11, 'GP': 17},
#  {'TeamID': 1260,
#   'TeamName': 'Loyola-Chicago',
#   'Wins': 22,
#   'Losses': 4,
#   'GP': 26},
#  {'TeamID': 1261, 'TeamName': 'LSU', 'Wins': 18, 'Losses': 9, 'GP': 27},
#  {'TeamID': 1262, 'TeamName': 'MA Lowell', 'Wins': 11, 'Losses': 12, 'GP': 23},
#  {'TeamID': 1263, 'TeamName': 'Maine', 'Wins': 2, 'Losses': 7, 'GP': 9},
#  {'TeamID': 1264, 'TeamName': 'Manhattan', 'Wins': 7, 'Losses': 13, 'GP': 20},
#  {'TeamID': 1265, 'TeamName': 'Marist', 'Wins': 12, 'Losses': 9, 'GP': 21},
#  {'TeamID': 1266, 'TeamName': 'Marquette', 'Wins': 13, 'Losses': 14, 'GP': 27},
#  {'TeamID': 1267, 'TeamName': 'Marshall', 'Wins': 15, 'Losses': 7, 'GP': 22},
#  {'TeamID': 1268, 'TeamName': 'Maryland', 'Wins': 15, 'Losses': 13, 'GP': 28},
#  {'TeamID': 1269,
#   'TeamName': 'Massachusetts',
#   'Wins': 8,
#   'Losses': 7,
#   'GP': 15},
#  {'TeamID': 1270, 'TeamName': 'McNeese St', 'Wins': 4, 'Losses': 14, 'GP': 18},
#  {'TeamID': 1271, 'TeamName': 'MD E Shore', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1272, 'TeamName': 'Memphis', 'Wins': 16, 'Losses': 8, 'GP': 24},
#  {'TeamID': 1273, 'TeamName': 'Mercer', 'Wins': 15, 'Losses': 11, 'GP': 26},
#  {'TeamID': 1274, 'TeamName': 'Miami FL', 'Wins': 10, 'Losses': 17, 'GP': 27},
#  {'TeamID': 1275, 'TeamName': 'Miami OH', 'Wins': 11, 'Losses': 11, 'GP': 22},
#  {'TeamID': 1276, 'TeamName': 'Michigan', 'Wins': 20, 'Losses': 4, 'GP': 24},
#  {'TeamID': 1277,
#   'TeamName': 'Michigan St',
#   'Wins': 15,
#   'Losses': 12,
#   'GP': 27},
#  {'TeamID': 1278, 'TeamName': 'Minnesota', 'Wins': 14, 'Losses': 15, 'GP': 29},
#  {'TeamID': 1279,
#   'TeamName': 'Mississippi',
#   'Wins': 16,
#   'Losses': 11,
#   'GP': 27},
#  {'TeamID': 1280,
#   'TeamName': 'Mississippi St',
#   'Wins': 15,
#   'Losses': 14,
#   'GP': 29},
#  {'TeamID': 1281, 'TeamName': 'Missouri', 'Wins': 16, 'Losses': 9, 'GP': 25},
#  {'TeamID': 1282,
#   'TeamName': 'Missouri KC',
#   'Wins': 7,
#   'Losses': 13,
#   'GP': 20},
#  {'TeamID': 1283,
#   'TeamName': 'Missouri St',
#   'Wins': 15,
#   'Losses': 7,
#   'GP': 22},
#  {'TeamID': 1284,
#   'TeamName': 'Monmouth NJ',
#   'Wins': 12,
#   'Losses': 8,
#   'GP': 20},
#  {'TeamID': 1285, 'TeamName': 'Montana', 'Wins': 10, 'Losses': 13, 'GP': 23},
#  {'TeamID': 1286,
#   'TeamName': 'Montana St',
#   'Wins': 11,
#   'Losses': 10,
#   'GP': 21},
#  {'TeamID': 1287,
#   'TeamName': 'Morehead St',
#   'Wins': 21,
#   'Losses': 7,
#   'GP': 28},
#  {'TeamID': 1288, 'TeamName': 'Morgan St', 'Wins': 12, 'Losses': 7, 'GP': 19},
#  {'TeamID': 1289, 'TeamName': 'Morris Brown', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1290,
#   'TeamName': 'MS Valley St',
#   'Wins': 2,
#   'Losses': 22,
#   'GP': 24},
#  {'TeamID': 1291,
#   'TeamName': "Mt St Mary's",
#   'Wins': 12,
#   'Losses': 10,
#   'GP': 22},
#  {'TeamID': 1292, 'TeamName': 'MTSU', 'Wins': 4, 'Losses': 18, 'GP': 22},
#  {'TeamID': 1293, 'TeamName': 'Murray St', 'Wins': 11, 'Losses': 13, 'GP': 24},
#  {'TeamID': 1294, 'TeamName': 'N Colorado', 'Wins': 8, 'Losses': 11, 'GP': 19},
#  {'TeamID': 1295,
#   'TeamName': 'N Dakota St',
#   'Wins': 15,
#   'Losses': 12,
#   'GP': 27},
#  {'TeamID': 1296, 'TeamName': 'N Illinois', 'Wins': 3, 'Losses': 16, 'GP': 19},
#  {'TeamID': 1297,
#   'TeamName': 'N Kentucky',
#   'Wins': 14,
#   'Losses': 11,
#   'GP': 25},
#  {'TeamID': 1298, 'TeamName': 'Navy', 'Wins': 15, 'Losses': 3, 'GP': 18},
#  {'TeamID': 1299, 'TeamName': 'NC A&T', 'Wins': 9, 'Losses': 10, 'GP': 19},
#  {'TeamID': 1300, 'TeamName': 'NC Central', 'Wins': 4, 'Losses': 9, 'GP': 13},
#  {'TeamID': 1301, 'TeamName': 'NC State', 'Wins': 13, 'Losses': 10, 'GP': 23},
#  {'TeamID': 1302, 'TeamName': 'NE Illinois', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1303, 'TeamName': 'NE Omaha', 'Wins': 5, 'Losses': 20, 'GP': 25},
#  {'TeamID': 1304, 'TeamName': 'Nebraska', 'Wins': 6, 'Losses': 20, 'GP': 26},
#  {'TeamID': 1305, 'TeamName': 'Nevada', 'Wins': 15, 'Losses': 10, 'GP': 25},
#  {'TeamID': 1306,
#   'TeamName': 'New Hampshire',
#   'Wins': 9,
#   'Losses': 9,
#   'GP': 18},
#  {'TeamID': 1307, 'TeamName': 'New Mexico', 'Wins': 4, 'Losses': 16, 'GP': 20},
#  {'TeamID': 1308,
#   'TeamName': 'New Mexico St',
#   'Wins': 9,
#   'Losses': 8,
#   'GP': 17},
#  {'TeamID': 1309,
#   'TeamName': 'New Orleans',
#   'Wins': 9,
#   'Losses': 15,
#   'GP': 24},
#  {'TeamID': 1310, 'TeamName': 'Niagara', 'Wins': 9, 'Losses': 11, 'GP': 20},
#  {'TeamID': 1311,
#   'TeamName': 'Nicholls St',
#   'Wins': 17,
#   'Losses': 7,
#   'GP': 24},
#  {'TeamID': 1312, 'TeamName': 'NJIT', 'Wins': 7, 'Losses': 12, 'GP': 19},
#  {'TeamID': 1313, 'TeamName': 'Norfolk St', 'Wins': 14, 'Losses': 7, 'GP': 21},
#  {'TeamID': 1314,
#   'TeamName': 'North Carolina',
#   'Wins': 18,
#   'Losses': 10,
#   'GP': 28},
#  {'TeamID': 1315,
#   'TeamName': 'North Dakota',
#   'Wins': 9,
#   'Losses': 17,
#   'GP': 26},
#  {'TeamID': 1316,
#   'TeamName': 'North Florida',
#   'Wins': 7,
#   'Losses': 14,
#   'GP': 21},
#  {'TeamID': 1317,
#   'TeamName': 'North Texas',
#   'Wins': 16,
#   'Losses': 9,
#   'GP': 25},
#  {'TeamID': 1318,
#   'TeamName': 'Northeastern',
#   'Wins': 10,
#   'Losses': 9,
#   'GP': 19},
#  {'TeamID': 1319,
#   'TeamName': 'Northern Arizona',
#   'Wins': 6,
#   'Losses': 16,
#   'GP': 22},
#  {'TeamID': 1320,
#   'TeamName': 'Northern Iowa',
#   'Wins': 8,
#   'Losses': 15,
#   'GP': 23},
#  {'TeamID': 1321,
#   'TeamName': 'Northwestern',
#   'Wins': 8,
#   'Losses': 15,
#   'GP': 23},
#  {'TeamID': 1322,
#   'TeamName': 'Northwestern LA',
#   'Wins': 10,
#   'Losses': 18,
#   'GP': 28},
#  {'TeamID': 1323,
#   'TeamName': 'Notre Dame',
#   'Wins': 11,
#   'Losses': 15,
#   'GP': 26},
#  {'TeamID': 1324, 'TeamName': 'Oakland', 'Wins': 12, 'Losses': 18, 'GP': 30},
#  {'TeamID': 1325, 'TeamName': 'Ohio', 'Wins': 15, 'Losses': 7, 'GP': 22},
#  {'TeamID': 1326, 'TeamName': 'Ohio St', 'Wins': 21, 'Losses': 9, 'GP': 30},
#  {'TeamID': 1327, 'TeamName': 'Okla City', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1328, 'TeamName': 'Oklahoma', 'Wins': 15, 'Losses': 10, 'GP': 25},
#  {'TeamID': 1329,
#   'TeamName': 'Oklahoma St',
#   'Wins': 20,
#   'Losses': 8,
#   'GP': 28},
#  {'TeamID': 1330,
#   'TeamName': 'Old Dominion',
#   'Wins': 14,
#   'Losses': 8,
#   'GP': 22},
#  {'TeamID': 1331,
#   'TeamName': 'Oral Roberts',
#   'Wins': 13,
#   'Losses': 10,
#   'GP': 23},
#  {'TeamID': 1332, 'TeamName': 'Oregon', 'Wins': 20, 'Losses': 6, 'GP': 26},
#  {'TeamID': 1333, 'TeamName': 'Oregon St', 'Wins': 16, 'Losses': 12, 'GP': 28},
#  {'TeamID': 1334, 'TeamName': 'Pacific', 'Wins': 8, 'Losses': 9, 'GP': 17},
#  {'TeamID': 1335, 'TeamName': 'Penn', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1336, 'TeamName': 'Penn St', 'Wins': 11, 'Losses': 14, 'GP': 25},
#  {'TeamID': 1337,
#   'TeamName': 'Pepperdine',
#   'Wins': 10,
#   'Losses': 12,
#   'GP': 22},
#  {'TeamID': 1338,
#   'TeamName': 'Pittsburgh',
#   'Wins': 10,
#   'Losses': 12,
#   'GP': 22},
#  {'TeamID': 1339, 'TeamName': 'Portland', 'Wins': 3, 'Losses': 15, 'GP': 18},
#  {'TeamID': 1340,
#   'TeamName': 'Portland St',
#   'Wins': 6,
#   'Losses': 12,
#   'GP': 18},
#  {'TeamID': 1341,
#   'TeamName': 'Prairie View',
#   'Wins': 16,
#   'Losses': 5,
#   'GP': 21},
#  {'TeamID': 1342,
#   'TeamName': 'Presbyterian',
#   'Wins': 6,
#   'Losses': 15,
#   'GP': 21},
#  {'TeamID': 1343, 'TeamName': 'Princeton', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1344,
#   'TeamName': 'Providence',
#   'Wins': 13,
#   'Losses': 13,
#   'GP': 26},
#  {'TeamID': 1345, 'TeamName': 'Purdue', 'Wins': 18, 'Losses': 9, 'GP': 27},
#  {'TeamID': 1346, 'TeamName': 'Quinnipiac', 'Wins': 9, 'Losses': 13, 'GP': 22},
#  {'TeamID': 1347, 'TeamName': 'Radford', 'Wins': 13, 'Losses': 12, 'GP': 25},
#  {'TeamID': 1348,
#   'TeamName': 'Rhode Island',
#   'Wins': 10,
#   'Losses': 15,
#   'GP': 25},
#  {'TeamID': 1349, 'TeamName': 'Rice', 'Wins': 12, 'Losses': 13, 'GP': 25},
#  {'TeamID': 1350, 'TeamName': 'Richmond', 'Wins': 12, 'Losses': 8, 'GP': 20},
#  {'TeamID': 1351, 'TeamName': 'Rider', 'Wins': 6, 'Losses': 17, 'GP': 23},
#  {'TeamID': 1352,
#   'TeamName': 'Robert Morris',
#   'Wins': 3,
#   'Losses': 15,
#   'GP': 18},
#  {'TeamID': 1353, 'TeamName': 'Rutgers', 'Wins': 15, 'Losses': 11, 'GP': 26},
#  {'TeamID': 1354,
#   'TeamName': 'S Carolina St',
#   'Wins': 1,
#   'Losses': 17,
#   'GP': 18},
#  {'TeamID': 1355,
#   'TeamName': 'S Dakota St',
#   'Wins': 15,
#   'Losses': 7,
#   'GP': 22},
#  {'TeamID': 1356,
#   'TeamName': 'S Illinois',
#   'Wins': 11,
#   'Losses': 14,
#   'GP': 25},
#  {'TeamID': 1357,
#   'TeamName': 'Sacred Heart',
#   'Wins': 9,
#   'Losses': 9,
#   'GP': 18},
#  {'TeamID': 1358,
#   'TeamName': 'Sam Houston St',
#   'Wins': 15,
#   'Losses': 9,
#   'GP': 24},
#  {'TeamID': 1359, 'TeamName': 'Samford', 'Wins': 4, 'Losses': 13, 'GP': 17},
#  {'TeamID': 1360, 'TeamName': 'San Diego', 'Wins': 3, 'Losses': 11, 'GP': 14},
#  {'TeamID': 1361,
#   'TeamName': 'San Diego St',
#   'Wins': 22,
#   'Losses': 4,
#   'GP': 26},
#  {'TeamID': 1362,
#   'TeamName': 'San Francisco',
#   'Wins': 11,
#   'Losses': 14,
#   'GP': 25},
#  {'TeamID': 1363,
#   'TeamName': 'San Jose St',
#   'Wins': 3,
#   'Losses': 16,
#   'GP': 19},
#  {'TeamID': 1364,
#   'TeamName': 'UC Santa Barbara',
#   'Wins': 20,
#   'Losses': 4,
#   'GP': 24},
#  {'TeamID': 1365,
#   'TeamName': 'Santa Clara',
#   'Wins': 11,
#   'Losses': 8,
#   'GP': 19},
#  {'TeamID': 1366, 'TeamName': 'Savannah St', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1367, 'TeamName': 'SC Upstate', 'Wins': 5, 'Losses': 17, 'GP': 22},
#  {'TeamID': 1368,
#   'TeamName': 'SE Louisiana',
#   'Wins': 8,
#   'Losses': 18,
#   'GP': 26},
#  {'TeamID': 1369,
#   'TeamName': 'SE Missouri St',
#   'Wins': 11,
#   'Losses': 16,
#   'GP': 27},
#  {'TeamID': 1370, 'TeamName': 'Seattle', 'Wins': 8, 'Losses': 11, 'GP': 19},
#  {'TeamID': 1371,
#   'TeamName': 'Seton Hall',
#   'Wins': 14,
#   'Losses': 13,
#   'GP': 27},
#  {'TeamID': 1372, 'TeamName': 'SF Austin', 'Wins': 13, 'Losses': 5, 'GP': 18},
#  {'TeamID': 1373, 'TeamName': 'Siena', 'Wins': 12, 'Losses': 5, 'GP': 17},
#  {'TeamID': 1374, 'TeamName': 'SMU', 'Wins': 11, 'Losses': 5, 'GP': 16},
#  {'TeamID': 1375,
#   'TeamName': 'South Alabama',
#   'Wins': 13,
#   'Losses': 11,
#   'GP': 24},
#  {'TeamID': 1376,
#   'TeamName': 'South Carolina',
#   'Wins': 6,
#   'Losses': 15,
#   'GP': 21},
#  {'TeamID': 1377,
#   'TeamName': 'South Dakota',
#   'Wins': 13,
#   'Losses': 11,
#   'GP': 24},
#  {'TeamID': 1378,
#   'TeamName': 'South Florida',
#   'Wins': 8,
#   'Losses': 13,
#   'GP': 21},
#  {'TeamID': 1379,
#   'TeamName': 'Southern Miss',
#   'Wins': 6,
#   'Losses': 17,
#   'GP': 23},
#  {'TeamID': 1380,
#   'TeamName': 'Southern Univ',
#   'Wins': 8,
#   'Losses': 11,
#   'GP': 19},
#  {'TeamID': 1381,
#   'TeamName': 'Southern Utah',
#   'Wins': 15,
#   'Losses': 4,
#   'GP': 19},
#  {'TeamID': 1382,
#   'TeamName': 'St Bonaventure',
#   'Wins': 16,
#   'Losses': 4,
#   'GP': 20},
#  {'TeamID': 1383,
#   'TeamName': 'St Francis NY',
#   'Wins': 9,
#   'Losses': 10,
#   'GP': 19},
#  {'TeamID': 1384,
#   'TeamName': 'St Francis PA',
#   'Wins': 6,
#   'Losses': 16,
#   'GP': 22},
#  {'TeamID': 1385, 'TeamName': "St John's", 'Wins': 16, 'Losses': 11, 'GP': 27},
#  {'TeamID': 1386,
#   'TeamName': "St Joseph's PA",
#   'Wins': 5,
#   'Losses': 15,
#   'GP': 20},
#  {'TeamID': 1387, 'TeamName': 'St Louis', 'Wins': 14, 'Losses': 6, 'GP': 20},
#  {'TeamID': 1388,
#   'TeamName': "St Mary's CA",
#   'Wins': 14,
#   'Losses': 9,
#   'GP': 23},
#  {'TeamID': 1389,
#   'TeamName': "St Peter's",
#   'Wins': 14,
#   'Losses': 11,
#   'GP': 25},
#  {'TeamID': 1390, 'TeamName': 'Stanford', 'Wins': 14, 'Losses': 13, 'GP': 27},
#  {'TeamID': 1391, 'TeamName': 'Stetson', 'Wins': 9, 'Losses': 13, 'GP': 22},
#  {'TeamID': 1392,
#   'TeamName': 'Stony Brook',
#   'Wins': 8,
#   'Losses': 14,
#   'GP': 22},
#  {'TeamID': 1393, 'TeamName': 'Syracuse', 'Wins': 16, 'Losses': 9, 'GP': 25},
#  {'TeamID': 1394,
#   'TeamName': 'TAM C. Christi',
#   'Wins': 2,
#   'Losses': 19,
#   'GP': 21},
#  {'TeamID': 1395, 'TeamName': 'TCU', 'Wins': 12, 'Losses': 14, 'GP': 26},
#  {'TeamID': 1396, 'TeamName': 'Temple', 'Wins': 5, 'Losses': 11, 'GP': 16},
#  {'TeamID': 1397, 'TeamName': 'Tennessee', 'Wins': 18, 'Losses': 8, 'GP': 26},
#  {'TeamID': 1398,
#   'TeamName': 'Tennessee St',
#   'Wins': 3,
#   'Losses': 19,
#   'GP': 22},
#  {'TeamID': 1399,
#   'TeamName': 'Tennessee Tech',
#   'Wins': 5,
#   'Losses': 22,
#   'GP': 27},
#  {'TeamID': 1400, 'TeamName': 'Texas', 'Wins': 19, 'Losses': 7, 'GP': 26},
#  {'TeamID': 1401, 'TeamName': 'Texas A&M', 'Wins': 8, 'Losses': 10, 'GP': 18},
#  {'TeamID': 1402, 'TeamName': 'Texas St', 'Wins': 17, 'Losses': 6, 'GP': 23},
#  {'TeamID': 1403,
#   'TeamName': 'Texas Tech',
#   'Wins': 17,
#   'Losses': 10,
#   'GP': 27},
#  {'TeamID': 1404, 'TeamName': 'TN Martin', 'Wins': 7, 'Losses': 16, 'GP': 23},
#  {'TeamID': 1405, 'TeamName': 'Toledo', 'Wins': 21, 'Losses': 8, 'GP': 29},
#  {'TeamID': 1406, 'TeamName': 'Towson', 'Wins': 4, 'Losses': 14, 'GP': 18},
#  {'TeamID': 1407, 'TeamName': 'Troy', 'Wins': 8, 'Losses': 17, 'GP': 25},
#  {'TeamID': 1408, 'TeamName': 'Tulane', 'Wins': 10, 'Losses': 13, 'GP': 23},
#  {'TeamID': 1409, 'TeamName': 'Tulsa', 'Wins': 9, 'Losses': 12, 'GP': 21},
#  {'TeamID': 1410, 'TeamName': 'UTRGV', 'Wins': 5, 'Losses': 10, 'GP': 15},
#  {'TeamID': 1411,
#   'TeamName': 'TX Southern',
#   'Wins': 15,
#   'Losses': 8,
#   'GP': 23},
#  {'TeamID': 1412, 'TeamName': 'UAB', 'Wins': 20, 'Losses': 7, 'GP': 27},
#  {'TeamID': 1413, 'TeamName': 'UC Davis', 'Wins': 9, 'Losses': 8, 'GP': 17},
#  {'TeamID': 1414, 'TeamName': 'UC Irvine', 'Wins': 16, 'Losses': 9, 'GP': 25},
#  {'TeamID': 1415,
#   'TeamName': 'UC Riverside',
#   'Wins': 14,
#   'Losses': 8,
#   'GP': 22},
#  {'TeamID': 1416, 'TeamName': 'UCF', 'Wins': 11, 'Losses': 12, 'GP': 23},
#  {'TeamID': 1417, 'TeamName': 'UCLA', 'Wins': 17, 'Losses': 9, 'GP': 26},
#  {'TeamID': 1418, 'TeamName': 'Louisiana', 'Wins': 15, 'Losses': 9, 'GP': 24},
#  {'TeamID': 1419, 'TeamName': 'ULM', 'Wins': 7, 'Losses': 19, 'GP': 26},
#  {'TeamID': 1420, 'TeamName': 'UMBC', 'Wins': 14, 'Losses': 6, 'GP': 20},
#  {'TeamID': 1421,
#   'TeamName': 'UNC Asheville',
#   'Wins': 10,
#   'Losses': 10,
#   'GP': 20},
#  {'TeamID': 1422,
#   'TeamName': 'UNC Greensboro',
#   'Wins': 21,
#   'Losses': 8,
#   'GP': 29},
#  {'TeamID': 1423,
#   'TeamName': 'UNC Wilmington',
#   'Wins': 6,
#   'Losses': 10,
#   'GP': 16},
#  {'TeamID': 1424, 'TeamName': 'UNLV', 'Wins': 10, 'Losses': 15, 'GP': 25},
#  {'TeamID': 1425, 'TeamName': 'USC', 'Wins': 22, 'Losses': 7, 'GP': 29},
#  {'TeamID': 1426,
#   'TeamName': 'UT Arlington',
#   'Wins': 10,
#   'Losses': 13,
#   'GP': 23},
#  {'TeamID': 1427,
#   'TeamName': 'UT San Antonio',
#   'Wins': 11,
#   'Losses': 11,
#   'GP': 22},
#  {'TeamID': 1428, 'TeamName': 'Utah', 'Wins': 12, 'Losses': 13, 'GP': 25},
#  {'TeamID': 1429, 'TeamName': 'Utah St', 'Wins': 19, 'Losses': 8, 'GP': 27},
#  {'TeamID': 1430,
#   'TeamName': 'Utah Valley',
#   'Wins': 9,
#   'Losses': 11,
#   'GP': 20},
#  {'TeamID': 1431, 'TeamName': 'UTEP', 'Wins': 9, 'Losses': 12, 'GP': 21},
#  {'TeamID': 1432, 'TeamName': 'Utica', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1433, 'TeamName': 'VCU', 'Wins': 19, 'Losses': 7, 'GP': 26},
#  {'TeamID': 1434, 'TeamName': 'Valparaiso', 'Wins': 8, 'Losses': 18, 'GP': 26},
#  {'TeamID': 1435, 'TeamName': 'Vanderbilt', 'Wins': 9, 'Losses': 16, 'GP': 25},
#  {'TeamID': 1436, 'TeamName': 'Vermont', 'Wins': 10, 'Losses': 5, 'GP': 15},
#  {'TeamID': 1437, 'TeamName': 'Villanova', 'Wins': 16, 'Losses': 6, 'GP': 22},
#  {'TeamID': 1438, 'TeamName': 'Virginia', 'Wins': 18, 'Losses': 6, 'GP': 24},
#  {'TeamID': 1439,
#   'TeamName': 'Virginia Tech',
#   'Wins': 15,
#   'Losses': 6,
#   'GP': 21},
#  {'TeamID': 1440, 'TeamName': 'VMI', 'Wins': 10, 'Losses': 12, 'GP': 22},
#  {'TeamID': 1441, 'TeamName': 'W Carolina', 'Wins': 9, 'Losses': 16, 'GP': 25},
#  {'TeamID': 1442, 'TeamName': 'W Illinois', 'Wins': 6, 'Losses': 15, 'GP': 21},
#  {'TeamID': 1443, 'TeamName': 'WKU', 'Wins': 20, 'Losses': 7, 'GP': 27},
#  {'TeamID': 1444, 'TeamName': 'W Michigan', 'Wins': 4, 'Losses': 16, 'GP': 20},
#  {'TeamID': 1445, 'TeamName': 'W Salem St', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1446, 'TeamName': 'W Texas A&M', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1447, 'TeamName': 'Wagner', 'Wins': 13, 'Losses': 7, 'GP': 20},
#  {'TeamID': 1448,
#   'TeamName': 'Wake Forest',
#   'Wins': 5,
#   'Losses': 16,
#   'GP': 21},
#  {'TeamID': 1449, 'TeamName': 'Washington', 'Wins': 5, 'Losses': 21, 'GP': 26},
#  {'TeamID': 1450,
#   'TeamName': 'Washington St',
#   'Wins': 14,
#   'Losses': 13,
#   'GP': 27},
#  {'TeamID': 1451, 'TeamName': 'Weber St', 'Wins': 14, 'Losses': 6, 'GP': 20},
#  {'TeamID': 1452,
#   'TeamName': 'West Virginia',
#   'Wins': 18,
#   'Losses': 9,
#   'GP': 27},
#  {'TeamID': 1453,
#   'TeamName': 'WI Green Bay',
#   'Wins': 8,
#   'Losses': 17,
#   'GP': 25},
#  {'TeamID': 1454,
#   'TeamName': 'WI Milwaukee',
#   'Wins': 10,
#   'Losses': 12,
#   'GP': 22},
#  {'TeamID': 1455, 'TeamName': 'Wichita St', 'Wins': 14, 'Losses': 5, 'GP': 19},
#  {'TeamID': 1456,
#   'TeamName': 'William & Mary',
#   'Wins': 7,
#   'Losses': 10,
#   'GP': 17},
#  {'TeamID': 1457, 'TeamName': 'Winthrop', 'Wins': 23, 'Losses': 1, 'GP': 24},
#  {'TeamID': 1458, 'TeamName': 'Wisconsin', 'Wins': 17, 'Losses': 12, 'GP': 29},
#  {'TeamID': 1459, 'TeamName': 'Wofford', 'Wins': 13, 'Losses': 9, 'GP': 22},
#  {'TeamID': 1460, 'TeamName': 'Wright St', 'Wins': 18, 'Losses': 6, 'GP': 24},
#  {'TeamID': 1461, 'TeamName': 'Wyoming', 'Wins': 14, 'Losses': 11, 'GP': 25},
#  {'TeamID': 1462, 'TeamName': 'Xavier', 'Wins': 13, 'Losses': 8, 'GP': 21},
#  {'TeamID': 1463, 'TeamName': 'Yale', 'Wins': 0, 'Losses': 0, 'GP': 0},
#  {'TeamID': 1464,
#   'TeamName': 'Youngstown St',
#   'Wins': 11,
#   'Losses': 12,
#   'GP': 23},
#  {'TeamID': 1465,
#   'TeamName': 'Cal Baptist',
#   'Wins': 9,
#   'Losses': 10,
#   'GP': 19},
#  {'TeamID': 1466,
#   'TeamName': 'North Alabama',
#   'Wins': 9,
#   'Losses': 11,
#   'GP': 20},
#  {'TeamID': 1467, 'TeamName': 'Merrimack', 'Wins': 9, 'Losses': 9, 'GP': 18},
#  {'TeamID': 1468, 'TeamName': 'Bellarmine', 'Wins': 11, 'Losses': 7, 'GP': 18},
#  {'TeamID': 1469, 'TeamName': 'Dixie St', 'Wins': 6, 'Losses': 13, 'GP': 19},
#  {'TeamID': 1470,
#   'TeamName': 'Tarleton St',
#   'Wins': 5,
#   'Losses': 10,
#   'GP': 15},
#  {'TeamID': 1471,
#   'TeamName': 'UC San Diego',
#   'Wins': 4,
#   'Losses': 10,
#   'GP': 14}]

# %%
summary_df = pd.DataFrame(team_list)
summary_df.head()

# Need to confirm "System Name" to use
final_massey = df_massey_2021.loc[(df_massey_2021.RankingDayNum == 133) & (df_massey_2021.SystemName == '7OT')]

# %%
df_massey_2021.SystemName.unique()
# Out:
# array(['AP', 'BNZ', 'BWE', 'DES', 'DII', 'DOK', 'EBP', 'HAS', 'INC',
#        'JNG', 'LEF', 'MAS', 'MOR', 'PGH', 'POM', 'SAG', 'SMS', 'TRK',
#        'TRP', 'USA', 'WIL', 'FAS', 'RTP', '7OT', 'BBT', 'CWL', 'DAV',
#        'KPK', 'DCI', 'NOL', 'RT', 'SFX', 'SPR', 'SRS', 'TPR', 'DOL',
#        'DUN', 'KCX', 'NET', 'COL', 'LOG', 'BIH', 'CBR', 'JJK', 'WLK',
#        'KRA', 'SEL', 'WMV', 'WOB', 'ARG', 'PIR', 'EMK', 'FDM', 'LAW',
#        'LMC', 'REW', 'RWP'], dtype=object)

# %%
rank_df = final_massey.merge(summary_df, how='left', on='TeamID')
rank_df.head()
# Out:
#    Season  RankingDayNum SystemName  TeamID  OrdinalRank     TeamName  Wins  \
# 0    2021            133        7OT    1101           66  Abilene Chr    19
# 1    2021            133        7OT    1102          323    Air Force     5
# 2    2021            133        7OT    1103          126        Akron    13
# 3    2021            133        7OT    1104            5      Alabama    24
# 4    2021            133        7OT    1105          314  Alabama A&M     6
#
#    Losses  GP
# 0       4  23
# 1      20  25
# 2       8  21
# 3       6  30
# 4       9  15

# %%
total_games = []

for index, row in df_2021.iterrows():
    mask = summary_df.loc[summary_df.TeamID == row.WTeamID]
    total_GP = mask.GP.values[0]
    total_games.append(total_GP)
    
len(total_games)
# Out:
# 3855

# %%
df_2021["WinningTeam"] = winning_teams
df_2021["LosingTeam"] = losing_teams

df_2021.head()
# Out:
#    Season  DayNum  WTeamID  WScore  LTeamID  LScore WLoc  NumOT  WFGM  WFGA  \
# 0    2021      23     1101      70     1190      47    N      0    20    49
# 1    2021      23     1104      81     1240      57    H      0    30    77
# 2    2021      23     1111      81     1354      61    A      0    32    62
# 3    2021      23     1113      94     1348      88    N      0    27    61
# 4    2021      23     1114      71     1341      66    N      0    22    51
#
#    ...  LOR  LDR  LAst  LTO  LStl  LBlk  LPF  WTGP      WinningTeam  \
# 0  ...   11   27     5   22     6     2    0    23      Abilene Chr
# 1  ...   18   28    10   20     5     2    0    30          Alabama
# 2  ...   12   18    12    9    13     0   14    24   Appalachian St
# 3  ...    7   26    14   16     8     2    0    25       Arizona St
# 4  ...    7   15    14   24    12     1    0    25  Ark Little Rock
#
#         LosingTeam
# 0             ETSU
# 1  Jacksonville St
# 2    S Carolina St
# 3     Rhode Island
# 4     Prairie View
#
# [5 rows x 37 columns]

# %%
df_2021_sub = df_2021
df_2021_sub['WTGP'] = total_games

df_2021_sub
# Out:
#       Season  DayNum  WTeamID  WScore  LTeamID  LScore WLoc  NumOT  WFGM  \
# 0       2021      23     1101      70     1190      47    N      0    20
# 1       2021      23     1104      81     1240      57    H      0    30
# 2       2021      23     1111      81     1354      61    A      0    32
# 3       2021      23     1113      94     1348      88    N      0    27
# 4       2021      23     1114      71     1341      66    N      0    22
# ...      ...     ...      ...     ...      ...     ...  ...    ...   ...
# 3850    2021     132     1104      80     1261      79    N      0    33
# 3851    2021     132     1159      85     1259      72    H      0    31
# 3852    2021     132     1222      91     1153      54    N      0    37
# 3853    2021     132     1228      91     1326      88    N      1    29
# 3854    2021     132     1382      74     1433      65    N      0    25
#
#       WFGA  ...  LFTM  LFTA  LOR  LDR  LAst  LTO  LStl  LBlk  LPF  WTGP
# 0       49  ...    14    17   11   27     5   22     6     2    0    23
# 1       77  ...    10    17   18   28    10   20     5     2    0    30
# 2       62  ...     6    11   12   18    12    9    13     0   14    24
# 3       61  ...    21    35    7   26    14   16     8     2    0    25
# 4       51  ...     4     4    7   15    14   24    12     1    0    25
# ...    ...  ...   ...   ...  ...  ...   ...  ...   ...   ...  ...   ...
# 3850    76  ...     9    13   15   26    10    5     6     5   13    30
# 3851    59  ...     9    16   12   19    12   12     2     1   13    15
# 3852    66  ...    10    15   14   17    11   10     2     5   12    26
# 3853    64  ...    22    30    8   27    11    8     7     4   26    29
# 3854    62  ...    15    20    3   23     9    9     4     4   18    20
#
# [3855 rows x 35 columns]

# %%
avg_df = df_2021_sub.groupby("WinningTeam").mean().reset_index(drop=True)

avg_df
# Out:
#      Season     DayNum  WTeamID     WScore      LTeamID     LScore     NumOT  \
# 0    2021.0  83.263158   1101.0  78.947368  1287.000000  59.789474  0.000000
# 1    2021.0  59.200000   1102.0  65.400000  1298.200000  59.000000  0.000000
# 2    2021.0  87.692308   1103.0  79.846154  1236.230769  68.000000  0.076923
# 3    2021.0  82.291667   1104.0  83.500000  1265.291667  69.125000  0.000000
# 4    2021.0  70.833333   1105.0  76.333333  1270.833333  66.666667  0.333333
# ..      ...        ...      ...        ...          ...        ...       ...
# 341  2021.0  82.153846   1459.0  77.307692  1285.000000  67.692308  0.000000
# 342  2021.0  73.722222   1460.0  84.944444  1302.777778  63.444444  0.000000
# 343  2021.0  70.142857   1461.0  85.500000  1291.142857  72.714286  0.142857
# 344  2021.0  53.846154   1462.0  78.769231  1258.846154  66.076923  0.076923
# 345  2021.0  83.545455   1464.0  77.545455  1291.272727  69.363636  0.181818
#
#           WFGM       WFGA      WFGM3  ...       LFTM       LFTA        LOR  \
# 0    27.842105  59.421053   8.473684  ...  13.736842  19.789474   6.947368
# 1    23.000000  48.200000   7.600000  ...  11.600000  18.000000   7.800000
# 2    27.307692  58.615385  10.692308  ...  10.538462  14.384615   9.307692
# 3    29.250000  65.375000  11.375000  ...  13.750000  19.625000  10.166667
# 4    27.500000  62.333333   6.833333  ...  15.666667  24.666667  11.000000
# ..         ...        ...        ...  ...        ...        ...        ...
# 341  28.076923  55.692308  10.846154  ...   8.615385  12.615385   8.307692
# 342  30.777778  62.055556   7.500000  ...   8.166667  12.277778   7.611111
# 343  28.785714  59.785714  11.285714  ...  15.142857  22.071429   8.357143
# 344  29.384615  59.307692   7.923077  ...   9.384615  13.307692   9.461538
# 345  27.545455  60.000000   6.636364  ...   9.636364  13.454545   8.000000
#
#            LDR       LAst        LTO      LStl      LBlk       LPF  WTGP
# 0    22.263158   9.526316  19.105263  7.263158  3.631579  4.263158  23.0
# 1    23.200000   9.400000  14.800000  5.400000  2.000000  4.000000  25.0
# 2    20.230769  10.615385  11.461538  5.076923  2.000000  5.384615  21.0
# 3    23.625000  10.750000  14.791667  7.875000  4.541667  4.791667  30.0
# 4    24.166667   9.333333  13.833333  8.000000  2.833333  0.000000  15.0
# ..         ...        ...        ...       ...       ...       ...   ...
# 341  20.230769  12.769231  12.307692  6.076923  2.384615  3.000000  22.0
# 342  21.222222  10.777778  12.111111  6.111111  2.500000  1.166667  24.0
# 343  24.428571  12.000000  13.857143  5.357143  3.428571  7.928571  25.0
# 344  22.384615  13.923077  11.615385  6.461538  2.076923  2.538462  21.0
# 345  23.090909  13.181818  14.090909  5.272727  3.181818  6.727273  23.0
#
# [346 rows x 34 columns]

# %%
df_2021.columns
# Out:
# Index(['Season', 'DayNum', 'WTeamID', 'WScore', 'LTeamID', 'LScore', 'WLoc',
#        'NumOT', 'WFGM', 'WFGA', 'WFGM3', 'WFGA3', 'WFTM', 'WFTA', 'WOR', 'WDR',
#        'WAst', 'WTO', 'WStl', 'WBlk', 'WPF', 'LFGM', 'LFGA', 'LFGM3', 'LFGA3',
#        'LFTM', 'LFTA', 'LOR', 'LDR', 'LAst', 'LTO', 'LStl', 'LBlk', 'LPF',
#        'WTGP', 'WinningTeam', 'LosingTeam'],
#       dtype='object')

# %%
num_cols = ['WScore', 'LScore', 'NumOT','WFGM', 'WFGA', 'WFGM3', 'WFGA3', 'WFTM', 'WFTA', 'WOR', 'WDR', 
            'WAst','WTO', 'WStl', 'WBlk', 'WPF', 'LFGM', 'LFGA', 'LFGM3', 'LFGA3', 'LFTM', 'LFTA', 
            'LOR', 'LDR', 'LAst', 'LTO', 'LStl', 'LBlk', 'LPF']

offense_metrics = ['WScore', 'LScore','WFGM', 'WFGA', 'WFGM3', 'WFGA3', 'WFTM', 'WFTA', 'WOR', 'WAst', 'WTO']
defense_metrics = ['WScore', 'LScore', 'WDR', 'WAst', 'WTO', 'WStl', 'WBlk', 'WPF']

# %%
df_numeric = df_2021[num_cols]
df_offense = df_2021[offense_metrics]
df_defense = df_2021[defense_metrics]

# %%
df_offense.corr()
# Out:
#           WScore    LScore      WFGM      WFGA     WFGM3     WFGA3      WFTM  \
# WScore  1.000000  0.585473  0.823706  0.477918  0.475502  0.286661  0.259593
# LScore  0.585473  1.000000  0.387951  0.266159  0.207912  0.111922  0.336304
# WFGM    0.823706  0.387951  1.000000  0.600419  0.352054  0.194150 -0.263773
# WFGA    0.477918  0.266159  0.600419  1.000000  0.201725  0.415250 -0.183045
# WFGM3   0.475502  0.207912  0.352054  0.201725  1.000000  0.727735 -0.231947
# WFGA3   0.286661  0.111922  0.194150  0.415250  0.727735  1.000000 -0.179024
# WFTM    0.259593  0.336304 -0.263773 -0.183045 -0.231947 -0.179024  1.000000
# WFTA    0.223141  0.324427 -0.253003 -0.170812 -0.251014 -0.201242  0.928163
# WOR     0.138237  0.017618  0.130949  0.570780 -0.054536  0.162787  0.074159
# WAst    0.554386  0.163421  0.599545  0.318994  0.500313  0.342634 -0.205342
# WTO    -0.039048  0.032665 -0.090529 -0.221226 -0.076043 -0.123375  0.111398
#
#             WFTA       WOR      WAst       WTO
# WScore  0.223141  0.138237  0.554386 -0.039048
# LScore  0.324427  0.017618  0.163421  0.032665
# WFGM   -0.253003  0.130949  0.599545 -0.090529
# WFGA   -0.170812  0.570780  0.318994 -0.221226
# WFGM3  -0.251014 -0.054536  0.500313 -0.076043
# WFGA3  -0.201242  0.162787  0.342634 -0.123375
# WFTM    0.928163  0.074159 -0.205342  0.111398
# WFTA    1.000000  0.131131 -0.199430  0.135496
# WOR     0.131131  1.000000  0.048435  0.056169
# WAst   -0.199430  0.048435  1.000000 -0.011550
# WTO     0.135496  0.056169 -0.011550  1.000000

# %%
for df in [df_numeric, df_offense, df_defense]:
    
    plt.figure(figsize=(10,6))
    sns.heatmap(df.corr())

    plt.show()

# %% [markdown]
# # Linear Models

# %%
target = df_numeric['WScore']
features = df_numeric.drop('WScore', axis=1)

X = np.array(features)
y = np.array(target)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123)

# %%
# train the model
reg = LinearRegression()
reg.fit(X_train, y_train)

#get predictions
in_sample_preds = reg.predict(X_train)
out_sample_preds = reg.predict(X_test)

#metric report
print("Linear Regression")
print("In-Sample R2: ", r2_score(y_train, in_sample_preds))
print("Out-Sample R2: ", r2_score(y_test, out_sample_preds))
print()
print("In-Sample MSE: ", mean_squared_error(y_train, in_sample_preds))
print("Out-Sample MSE: ", mean_squared_error(y_test, out_sample_preds))
print()
print("In-Sample MAE: ", mean_absolute_error(y_train, in_sample_preds))
print("Out-Sample MAE: ", mean_absolute_error(y_test, out_sample_preds))

# predicted vs actual
plt.figure(figsize=(10,6))
plt.scatter(y_test, out_sample_preds)
plt.plot(y_test, y_test)

plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Actual vs Predicted")

plt.show()
# Out:
# Linear Regression
# In-Sample R2:  1.0
# Out-Sample R2:  1.0
#
# In-Sample MSE:  2.250473849872529e-28
# Out-Sample MSE:  2.3855317480426634e-28
#
# In-Sample MAE:  1.120418068742337e-14
# Out-Sample MAE:  1.1621198311199563e-14

# %%
# train the model
ridge = Ridge()
ridge.fit(X_train, y_train)

#get predictions
in_sample_preds = ridge.predict(X_train)
out_sample_preds = ridge.predict(X_test)

#metric report
print("Ridge Regression")
print("In-Sample R2: ", r2_score(y_train, in_sample_preds))
print("Out-Sample R2: ", r2_score(y_test, out_sample_preds))
print()
print("In-Sample MSE: ", mean_squared_error(y_train, in_sample_preds))
print("Out-Sample MSE: ", mean_squared_error(y_test, out_sample_preds))
print()
print("In-Sample MAE: ", mean_absolute_error(y_train, in_sample_preds))
print("Out-Sample MAE: ", mean_absolute_error(y_test, out_sample_preds))

# predicted vs actual
plt.figure(figsize=(10,6))
plt.scatter(y_test, out_sample_preds)
plt.plot(y_test, y_test)

plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Actual vs Predicted")

plt.show()
# Out:
# Ridge Regression
# In-Sample R2:  0.9999999975399188
# Out-Sample R2:  0.9999999977662729
#
# In-Sample MSE:  2.71981659355164e-07
# Out-Sample MSE:  2.46782950954491e-07
#
# In-Sample MAE:  0.00041160796537697544
# Out-Sample MAE:  0.00039614898512985104

# %%
# train the model
dt = DecisionTreeRegressor()
dt.fit(X_train, y_train)

#get predictions
in_sample_preds = dt.predict(X_train)
out_sample_preds = dt.predict(X_test)

#metric report
print("Decision Tree")
print("In-Sample R2: ", r2_score(y_train, in_sample_preds))
print("Out-Sample R2: ", r2_score(y_test, out_sample_preds))
print()
print("In-Sample MSE: ", mean_squared_error(y_train, in_sample_preds))
print("Out-Sample MSE: ", mean_squared_error(y_test, out_sample_preds))
print()
print("In-Sample MAE: ", mean_absolute_error(y_train, in_sample_preds))
print("Out-Sample MAE: ", mean_absolute_error(y_test, out_sample_preds))

# predicted vs actual
plt.figure(figsize=(10,6))
plt.scatter(y_test, out_sample_preds)
plt.plot(y_test, y_test)

plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Actual vs Predicted")

plt.show()
# Out:
# Decision Tree
# In-Sample R2:  1.0
# Out-Sample R2:  0.9163187286302581
#
# In-Sample MSE:  0.0
# Out-Sample MSE:  9.245136186770427
#
# In-Sample MAE:  0.0
# Out-Sample MAE:  2.025940337224384

# %%
# train the model
rf = RandomForestRegressor()
rf.fit(X_train, y_train)

#get predictions
in_sample_preds = rf.predict(X_train)
out_sample_preds = rf.predict(X_test)

#metric report
print("Random Forest")
print("In-Sample R2: ", r2_score(y_train, in_sample_preds))
print("Out-Sample R2: ", r2_score(y_test, out_sample_preds))
print()
print("In-Sample MSE: ", mean_squared_error(y_train, in_sample_preds))
print("Out-Sample MSE: ", mean_squared_error(y_test, out_sample_preds))
print()
print("In-Sample MAE: ", mean_absolute_error(y_train, in_sample_preds))
print("Out-Sample MAE: ", mean_absolute_error(y_test, out_sample_preds))

# predicted vs actual
plt.figure(figsize=(10,6))
plt.scatter(y_test, out_sample_preds)
plt.plot(y_test, y_test)

plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Actual vs Predicted")

plt.show()
# Out:
# Random Forest
# In-Sample R2:  0.9961341288809948
# Out-Sample R2:  0.9780137485262443
#
# In-Sample MSE:  0.42740298313878095
# Out-Sample MSE:  2.4290487678339825
#
# In-Sample MAE:  0.43029831387808043
# Out-Sample MAE:  1.1087678339818419
